# %% [markdown]
# # Second exercise (Chapter 6 & 8)
#
# In this exercise we consider Chapters 6 & 8 of the book "Deep Learning". The exercise focuses on implementing a small feedforward neural network and training it on the MNIST dataset.
#
# We provide code for structure and utility, you have to **fill in the TODO-gaps**.
# It might initially look like a lot of unnecessary code, but it keeps the network extensible. In the following exercises you can reuse what you've done here. Most common neural network libraries (*pytorch*, *tensorflow/keras*, …) are similarly structured, hence they will be easy to use once you've finished this notebook. As we will be using *pytorch* towards the end of the lecture, our API resembles the API of the pytorch framework.
#
#
# We will implement two different cost functions and play a bit with the value of the different hyperparameters to see how performances change as a function of those. In particular, we will focus on
#
# * Sigmoid Neurons
# * Stochastic Gradient Descent
# * Quadratic Cost Function
# * Cross Entropy Cost Function
# * Learning Rate
# * Generalization
#
# Note that we'll implement all of these operations to operate on mini-batches of data.

# %%
# Some imports used in the code below

from typing import Iterable, List, Optional, Tuple  # type annotations
import pickle  # data loading
import gzip  # data loading

import numpy as np  # linear algebra
import matplotlib.pyplot as plt  # plotting
import scipy.optimize  # gradient check

# %% [markdown]
# The cell below contains the two main classes to structure your network.
#
# **Parameter** is used to represent trainable variables in the network, e.g., a layer's weights $w$. The weights themself are a *numpy array* as the parameter's `data` attribute. The associated parameter gradient (e.g. $\frac{\partial L}{\partial w}$) can be stored in the `grad` attribute.
#
#
#
# **Module** is the base class for all parts of the network (activations, layers, …) and even the network itself. They all have to implement the `forward` and `backward` methods. For backpropagation activation will flow *forward* and gradient will flow *backward* through the *network graph and it's modules*.
#
# Additional module provides utility to check the correctness of implementation by approximating *backward* with [finite difference approximations](https://en.wikipedia.org/wiki/Finite_difference#Relation_with_derivatives)  of *forward*.
#
# *Note:* All modules operate on batches of samples. E.g. the input shape of `Linear.forward` is `(batch_size, feature_shape, 1)` (we will use the last dimension in future exercises).

# %%
class Parameter:
    """A trainable parameter.

    This class not only stores the value of the parameter (self.data) but also tensors/
    properties associated with it, such as the gradient (self.grad) of the current backward
    pass.
    """

    def __init__(self, data: np.ndarray, grad: Optional[np.ndarray] = None, name=None):
        self.data = data  # type: np.ndarray
        self.grad = grad  # type: Optional[np.ndarray]
        self.name = name  # type: Optional[str]
        self.state_dict = dict()  # dict to store additional, optional information
        
        
class Module:
    """The base class all network modules must inherit from."""

    def __init__(self):
        # Cache of the input of the forward pass.
        # We need it during the backward pass in most layers,
        #  e.g., to compute the gradient w.r.t to the weights.
        self.input_cache = None

    def __call__(self, *args) -> np.ndarray:
        """Alias for forward, convenience function."""
        return self.forward(*args)

    def forward(self, *args) -> np.ndarray:
        """Compute the forward pass through the module.

        Args:
           args: The inputs, e.g., the output of the previous layer.
        """
        raise NotImplementedError

    def backward(self, grad: np.ndarray) -> np.ndarray:
        """Compute the backward pass through the module.

        This method computes the gradients with respect to the trainable
        parameters and with respect to the first input.
        If the module has trainable parameters, this method needs to update
        the respective parameter.grad property.

        Args:
            grad: The gradient of the following layer.

        Returns:
            The gradient with respect to the first input argument. In general
            it might be useful to return the gradients w.r.t. to all inputs, we
            omit this here to keep things simple.
        """
        raise NotImplementedError

    def parameters(self) -> List[Parameter]:
        """Return the module parameters."""
        return []  # default to empty list

    def check_gradients(self, input_args: Tuple[np.ndarray]):
        """Verify the implementation of the gradients.

        This includes the gradient with respect to the input as well as the
        gradients w.r.t. the parameters if the module contains any.

        As the scipy grad check only works on scalar functions, we compute
        the sum over the output to obtain a scalar.
        """
        assert isinstance(input_args, tuple), (
            "input_args must be a tuple but is {}".format(type(input_args)))
        TOLERANCE = 1e-6
        self.check_gradients_wrt_input(input_args, TOLERANCE)
        self.check_gradients_wrt_params(input_args, TOLERANCE)

    def _zero_grad(self):
        """(Re-) intialize the param's grads to 0. Helper for grad checking."""
        for p in self.parameters():
            p.grad = np.zeros_like(p.data)

    def check_gradients_wrt_input(self, input_args: Tuple[np.ndarray],
                                  tolerance: float):
        """Verify the implementation of the module's gradient w.r.t. input."""

        def output_given_input(x: np.ndarray):
            """Wrap self.forward for scipy.optimize.check_grad."""
            # we only compute the gradient w.r.t. to the first input arg.
            args = (x.reshape(input_args[0].shape),) + input_args[1:]
            return np.sum(self.forward(*args))

        def grad_given_input(x: np.ndarray):
            """Wrap self.backward for scipy.optimize.check_grad."""
            self._zero_grad()
            # run self.forward to store the new input
            args = (x.reshape(input_args[0].shape),) + input_args[1:]
            out = self.forward(*args)
            # compute the gradient w.r.t. to the input
            return np.ravel(self.backward(np.ones_like(out)))

        error = scipy.optimize.check_grad(
            output_given_input, grad_given_input, np.ravel(input_args[0]))
        num_outputs = np.prod(self.forward(*input_args).shape)
        if np.squeeze(error) / num_outputs > tolerance:
            raise RuntimeError("Check of gradient w.r.t. to input for {} failed."
                               "Error {:.4E} > {:.4E}."
                               .format(self, np.squeeze(error), tolerance))

    def check_gradients_wrt_params(self, input_args: Tuple[np.ndarray],
                                   tolerance: float):
        """Verify the implementation of the module's gradient w.r.t. params."""
        for param in self.parameters():
            def output_given_params(new_param: np.ndarray):
                """Wrap self.forward, change the parameters to new_param."""
                param.data = new_param.reshape(param.data.shape)
                return np.sum(self.forward(*input_args))

            def grad_given_params(new_param: np.ndarray):
                self._zero_grad()
                param.data = new_param.reshape(param.data.shape)
                out = self.forward(*input_args)
                # compute the gradient w.r.t. to param
                self.backward(np.ones_like(out))
                return np.ravel(param.grad)
            # flatten the param as scipy can only handle 1D params
            param_init = np.ravel(np.copy(param.data))
            error = scipy.optimize.check_grad(output_given_params,
                                              grad_given_params,
                                              param_init)
            num_outputs = np.prod(self.forward(*input_args).shape)
            if np.squeeze(error) / num_outputs > tolerance:
                raise RuntimeError("Check of gradient w.r.t. to param '{}' for"
                                   "{} failed. Error {:.4E} > {:.4E}."
                                   .format(param.name, self, error, tolerance))

# %% [markdown]
# # Nonlinearities
#
# ## Sigmoid
#
# Implement your first network module: The sigmoid activation function.
#
# Verify your sigmoid function by plotting.

# %%
class Sigmoid(Module):
    def _sigmoid(self, z: np.ndarray) -> np.ndarray:
        return 1.0 / (1.0 + np.exp(-z))

    def forward(self, z: np.ndarray) -> np.ndarray:
        assert len(z.shape) == 3, ("z.shape should be (batch_size, input_size, 1)"
                                   " but is {}.".format(z.shape))
        h = self._sigmoid(z)
        # here it's useful to store the activation 
        #  instead of the input
        self.input_cache = h
        return h

    def backward(self, grad: np.ndarray) -> np.ndarray:
        h = self.input_cache
        grad_sig = h * (1 - h)
        return grad_sig * grad

# %%
x = np.linspace(-4, +4, 100)
sigmoid = Sigmoid()

y = np.ravel(sigmoid(x.reshape(-1, 1, 1)))
# equal to call of sigmoid.forward(x)
    
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Relu
#
# Implement Relu and plot for verification

# %%
class Relu(Module):
    def forward(self, z: np.ndarray) -> np.ndarray:
        assert len(z.shape) == 3, ("z.shape should be (batch_size, input_size, 1)"
                                   " but is {}.".format(z.shape))
        self.input_cache = z
        return np.maximum(0.0, z)

    def backward(self, grad: np.ndarray) -> np.ndarray:
        z = self.input_cache
        grad_relu = np.ones_like(z)
        grad_relu[z < 0.0] = 0.0
        return grad_relu * grad

# %%
# Plot Relu

x = np.linspace(-4, +4, 100)
relu = Relu()

y = np.ravel(relu(x.reshape(-1, 1, 1)))
    
plt.plot(x,y)
plt.xlabel('input')
plt.ylabel('output')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Softmax
#
# Implement the numerical stable softmax. We will not need the backward pass.

# %%
class Softmax(Module):
    def _softmax(self, z):
        # don't reduce (sum) over batch axis
        reduction_axes = tuple(range(1, len(z.shape))) 
        
        # START TODO ################
        z_max = np.max(z, axis=reduction_axes, keepdims=True)
        z_shift = z - z_max
        e_z = np.exp(z_shift)
        h = e_z / np.sum(e_z, axis=reduction_axes, keepdims=True)
        return h
    
    def forward(self, z: np.ndarray) -> np.ndarray:
        h = self._softmax(z)
        return h

    def backward(self, grad) -> np.ndarray:
        error_msg = ("Softmax doesn't need to implement a gradient here, as it's"
                     "only needed in CrossEntropyLoss, where we can simplify"
                     "the gradient for the combined expression.")
        raise NotImplementedError(error_msg)

# %%
# Check your softmax
softmax = Softmax()
x = np.array([1.0, 2.0, 3.0, 4.0, 1.0, 2.0, 3.0]).reshape(1, -1, 1)

# Testcase from https://en.wikipedia.org/wiki/Softmax_function#Example
np.testing.assert_allclose(
    np.ravel(softmax(x)), 
    [0.02364054, 0.06426166, 0.1746813, 0.474833, 0.02364054, 0.06426166, 0.1746813],
    rtol=1e-5, err_msg="Softmax is not correct implemented")

# %% [markdown]
# # Linear Layer
#
# Implement a linear (in other frameworks also called dense or fully connected) network layer.
# Here you also have to use the Parameter class.

# %%
class Linear(Module):

    def __init__(self, in_features: int, out_features: int):
        super().__init__()
        
        w_data = 0.01 * np.random.randn(out_features, in_features)
        self.W = Parameter(data=w_data, grad=0, name="W")
        
        b_data = 0.01 * np.ones((out_features, 1))
        self.b = Parameter(data=b_data, grad=0, name="b")

    def forward(self, x: np.ndarray) -> np.ndarray:
        assert len(x.shape) == 3, ("x.shape should be (batch_size, input_size, 1)"
                                   " but is {}.".format(x.shape))
        self.input_cache = x
        z =  self.W.data @ x + self.b.data
        return z

    def backward(self, grad: np.ndarray) -> np.ndarray:
        x = self.input_cache
        # remember that input has a batch dimension when transposing, i.e.,
        # we need to use np.transpose instead of x.T
        #x_transpose = np.transpose(x, [0, 2, 1])

        input_grad = np.einsum('abc,bd->adc', grad, self.W.data) 
        self.W.grad += np.einsum('abc,adc->db', x, grad)
        self.b.grad += np.sum(grad, axis=0)
        
        return input_grad

    def parameters(self) -> List[Parameter]:
        return [self.W, self.b]

# %% [markdown]
# # Cost Functions

# %%
# Define the Cross-Entropy cost functions
class CrossEntropyLoss(Module):
    """Compute the cross entropy."""

    def __init__(self):
        super().__init__()
        self.softmax = Softmax()

    def forward(self, a: np.ndarray, y: np.ndarray) -> np.ndarray:
        """Compute the cross entropy, mean over batch size."""
        a = self.softmax(a)
        self.input_cache = a, y
        # compute the mean over the batch
        return -np.sum(np.log(a[y == 1])) / len(a)

    def backward(self, _=None) -> np.ndarray:
        # we introduce the argument _ here, to have a unified interface with
        # other Module objects. This simplifies code for gradient checking. 
        # We don't need this arg.
        a, y = self.input_cache
        grad = (a - y) / len(y)
        grad = grad[:,:,np.newaxis]

        assert len(grad.shape) == 3, ("CrossEntropyLoss.backward should return (batch_size, grad_size, 1)"
                                      " but is {}.".format(grad.shape))
        return grad


class MSELoss(Module):
    """Compute the mean squared error loss."""

    def forward(self, a: np.ndarray, y: np.ndarray) -> np.ndarray:
        self.input_cache = a, y
        return np.sum(0.5 * np.linalg.norm(a - y, axis=-1)**2) / len(a)

    def backward(self, _=None):
        # we introduce the argument _ here, to have a unified interface with
        # other Module objects. This simplifies code for gradient checking. 
        # We don't need this arg
        a, y = self.input_cache
        grad = (a - y) / len(y)
        grad = grad[:,:,np.newaxis]
        
        assert len(grad.shape) == 3, ("MSELossCrossEntropyLoss.backward should return (batch_size, grad_size, 1)"
                                      " but is {}.".format(grad.shape))
        return grad

# %% [markdown]
# # Sequential Network

# %%
class Sequential(Module):
    """A sequential container to stack modules.

    Modules will be added to it in the order they are passed to the
    constructor.

    Example network with one hidden layer:
    model = Sequential(
                  Linear(5,10),
                  ReLU(),
                  Linear(10,10),
                )
    """
    def __init__(self, *args: List[Module]):
        super().__init__()
        self.modules = args

    def forward(self, x: np.ndarray) -> np.ndarray:
        for m in self.modules:
            x = m(x)
        return x

    def backward(self, grad: np.ndarray) -> np.ndarray:
        for m in self.modules[::-1]:
            grad = m.backward(grad)
        return grad

    def parameters(self) -> List[Parameter]:
        # iterate over modules and retrieve their parameters, iterate over
        # parameters to flatten the list
        return [param for module in self.modules
                for param in module.parameters()]

# %% [markdown]
# # One hot encoding
# To handle categorical data, we need to implement the one_hot_encoding utility function.

# %%
def one_hot_encoding(y: np.ndarray, num_classes: int) -> np.ndarray:
    """Convert integer labels to one hot encoding.

    Example: y=[1, 2] --> [[0, 1, 0], [0, 0, 1]]
    """
    encoded = np.zeros((len(y), num_classes))
    encoded[np.arange(len(y)), y] = 1
    return encoded

y = np.array([1, 2, 0])
np.testing.assert_equal(one_hot_encoding(y, 3), [[0, 1, 0], [0, 0, 1], [1, 0, 0]])

# %% [markdown]
# # Gradient Check
#
# Gradient checking is a useful utility to check, whether forward and backward pass are matching.
# Backward passes are approximated by finite differences of the forward pass.
# We have implemented the gradient checking in the Module class for you. As all classes we defined up to here inherit from Module, we can run `check_gradients`.

# %%
input_vector = np.random.uniform(-1., 1., size=(2, 10, 1))
input_args = (input_vector,)

# layers + activations
Relu().check_gradients(input_args)
Sigmoid().check_gradients(input_args)
Linear(10, 30).check_gradients(input_args)

# MLP
Sequential(
    Linear(10,30), Sigmoid(),
    Linear(30,20), Sigmoid()
    ).check_gradients(input_args)

# losses
input_args_losses = (one_hot_encoding(np.array([1, 2]), 3),  # a
                     one_hot_encoding(np.array([1, 1]), 3))  # y (ground truth)
MSELoss().check_gradients(input_args_losses)
CrossEntropyLoss().check_gradients(input_args_losses)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-16-af2979e47180> in <module>()
#      11     Linear(10,30), Sigmoid(),
#      12     Linear(30,20), Sigmoid(), Softmax()
# ---> 13     ).check_gradients(input_args)
#      14
#      15 # losses
#
# <ipython-input-2-16a99e49aa20> in check_gradients(self, input_args)
#      69             "input_args must be a tuple but is {}".format(type(input_args)))
#      70         TOLERANCE = 1e-6
# ---> 71         self.check_gradients_wrt_input(input_args, TOLERANCE)
#      72         self.check_gradients_wrt_params(input_args, TOLERANCE)
#      73
#
# <ipython-input-2-16a99e49aa20> in check_gradients_wrt_input(self, input_args, tolerance)
#      97
#      98         error = scipy.optimize.check_grad(
# ---> 99             output_given_input, grad_given_input, np.ravel(input_args[0]))
#     100         num_outputs = np.prod(self.forward(*input_args).shape)
#     101         if np.squeeze(error) / num_outputs > tolerance:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in check_grad(func, grad, x0, *args, **kwargs)
#     769         raise ValueError("Unknown keyword arguments: %r" %
#     770                          (list(kwargs.keys()),))
# --> 771     return sqrt(sum((grad(x0, *args) -
#     772                      approx_fprime(x0, func, step, *args))**2))
#     773
#
# <ipython-input-2-16a99e49aa20> in grad_given_input(x)
#      94             out = self.forward(*args)
#      95             # compute the gradient w.r.t. to the input
# ---> 96             return np.ravel(self.backward(np.ones_like(out)))
#      97
#      98         error = scipy.optimize.check_grad(
#
# <ipython-input-11-ce7b94242591> in backward(self, grad)
#      23     def backward(self, grad: np.ndarray) -> np.ndarray:
#      24         for m in self.modules[::-1]:
# ---> 25             grad = m.backward(grad)
#      26         return grad
#      27
#
# <ipython-input-7-783fc4894753> in backward(self, grad)
#      19                      "only needed in CrossEntropyLoss, where we can simplify"
#      20                      "the gradient for the combined expression.")
# ---> 21         raise NotImplementedError(error_msg)
#
# NotImplementedError: Softmax doesn't need to implement a gradient here, as it'sonly needed in CrossEntropyLoss, where we can simplifythe gradient for the combined expression.

# %% [markdown]
# # Optimizers
#
# Below you see the base class for all optimizers. An Optimizer needs to implement the `step()` function, which updates the parameters passed to the constructor.

# %%
class Optimizer:
    """The base class for optimizers.

    All optimizers must implement a step() method that updates the parameters.
    The general optimization loop then looks like this:

    for inputs, targets in dataset:
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_fn(outputs, targets)
        loss.backward()
        optimizer.step()

    `zero_grad` initializes the gradients of the parameters to zero. This
    allows to accumulate gradients (instead of replacing it) during
    backpropagation, which is e.g. useful for skip connections.
    """

    def __init__(self, params: Iterable[Parameter]):
        """
        Args:
            params: The parameters to be optimized.
        """
        self._params = params

    def step(self) -> None:
        """Update the parameters."""
        raise NotImplementedError

    def zero_grad(self) -> None:
        """Clear the gradients of all optimized parameters."""
        for param in self._params:
            assert isinstance(param, Parameter)
            param.grad = np.zeros_like(param.data)

# %% [markdown]
# ## SGD
#
# Implement stochastic gradient descent (Chapter 5, Chapter 8).
# The momentum parameter improves training speed (Chapter 8.3).

# %%
class SGD(Optimizer):
    """Stochastic Gradient Descent (SGD) optimizer with optional Momentum."""

    def __init__(self, params: Iterable[Parameter], lr: float,
                 momentum: Optional[float] = None):
        super().__init__(params)
        self.lr = lr
        self.momentum = momentum
        if momentum:
            for param in self._params:
                param.state_dict["velocity"] = np.zeros_like(param.data)

    def step(self):
        for p in self._params:
            if self.momentum:
                # SGD with Momentum
                p.state_dict["velocity"] *= self.momentum
                p.state_dict["velocity"] -= self.lr * p.grad
                p.data += p.state_dict["velocity"]
            else:
                # Standard SGD
                p.data -= self.lr * p.grad

# %% [markdown]
# ## Data Loading

# %%
def load_mnist_data():
    """Loads the data, returns training_data, validation_data, test_data."""
    with gzip.open('mnist.pkl.gz', 'rb') as f:
        return pickle.load(f, encoding='latin1')


def minibatched(data: np.ndarray, batch_size: int) -> List[np.ndarray]:
    assert len(data) % batch_size == 0, ("Data length {} is not multiple of batch size {}"
                                         .format(len(data), batch_size))
    return data.reshape(-1, batch_size, *data.shape[1:])


(x_train, y_train), (x_val, y_val), (x_test, y_test) = load_mnist_data()
x_train = np.expand_dims(x_train, axis=-1)
x_val = np.expand_dims(x_val, axis=-1)
x_test = np.expand_dims(x_test, axis=-1)

num_classes = 10
y_train = one_hot_encoding(y_train, num_classes)
y_val = one_hot_encoding(y_val, num_classes)
y_test = one_hot_encoding(y_test, num_classes)

# %% [markdown]
# ## Training
#
# Implement the actual training loop.

# %%
def accuracy(y, predictions, y_is_onehot: bool = False) -> float:
    y_predicted = np.argmax(predictions, axis=-1)
    y = np.argmax(y, axis=-1)
    return np.sum(np.equal(y_predicted, y)) / len(y)


def evaluate(data, labels, model, batch_size):
    predictions = []
    eval_cost = 0.
    data_batched = minibatched(data, batch_size)
    labels_batched = minibatched(labels, batch_size)

    for x, y in zip(data_batched, labels_batched):
        # note that when using cross entropy loss, the softmax is included in the
        # loss and we'd need to apply it manually here to obtain the output as probabilities.
        # However, softmax only rescales the outputs and doesn't change the argmax,
        # so we'll skip this here, as we're only interested in the class prediction.
        h_1 = np.squeeze(model(x))
        predictions.append(h_1)
        eval_cost += loss_fn(h_1, y)
    predictions = np.array(predictions).reshape(-1, 10)
    eval_accuracy = accuracy(y_val, predictions, False)
    return eval_accuracy, eval_cost


def train(model, loss_fn, optimizer, x_train, y_train, x_val, y_val, num_epochs, batch_size):
    
    train_costs, train_accuracies = np.zeros(num_epochs), np.zeros(num_epochs)
    eval_costs, eval_accuracies = np.zeros(num_epochs), np.zeros(num_epochs)
    ix = np.arange(len(x_train))
    
    for epoch in range(num_epochs):
        print("Epoch {} / {}:".format(epoch + 1, num_epochs))
        training_predictions = []
        
        np.random.shuffle(ix)
        x_train_batched = minibatched(x_train[ix], batch_size)
        y_train_batched = minibatched(y_train[ix], batch_size)
        
        # train for one epoch
        for x_batch, y_batch in zip(x_train_batched, y_train_batched):
            # Foward
            optimizer.zero_grad()
            y_pred = np.squeeze(model(x_batch))
            loss = loss_fn(y_pred, y_batch)
            
            # Backward
            grad_wrt_y_pred = loss_fn.backward()
            model.backward(grad_wrt_y_pred)
            
            # Param update
            optimizer.step()
            
            # Bookkeeping
            training_predictions.append(y_pred)
            train_costs[epoch] += loss
       
        training_predictions = np.array(training_predictions).reshape(-1, 10)
        train_accuracies[epoch] = accuracy(y_train[ix], training_predictions, False)
        print("  Training Accuracy: {:.4f}".format(train_accuracies[epoch]))
        print("  Training Cost: {:.4f}".format(train_costs[epoch]))
        eval_accuracies[epoch], eval_costs[epoch] = evaluate(x_val, y_val, model, batch_size)
        print("  Eval Accuracy: {:.4f}".format(eval_accuracies[epoch]))
    return train_costs, train_accuracies, eval_costs, eval_accuracies

# %% [markdown]
# ** Your feedback on exercise 2.2: **

# %% [markdown]
# # Experiments
#
# Apply it on a sequential model (linear, sigmoid, linear, softmax (included in cross entropy!). Use the cross entropy loss and sgd with momentum. Use the hyperparameters defined below.
#
# What is the best accuracy you can achieve?

# %%
num_epochs = 10
batch_size = 50
learning_rate = 0.1
momentum = 0.9
linear_units = 30

model = Sequential(Linear(784,linear_units), Sigmoid(), Linear(linear_units,10))
params = model.parameters()
optim = SGD(params, learning_rate, momentum)
loss_fn = CrossEntropyLoss()

train(model, loss_fn, optim, x_train, y_train, x_val, y_val, num_epochs, batch_size);
# Out:
# Epoch 1 / 10:
#   Training Accuracy: 0.8496
#   Training Cost: 480.6184
#   Eval Accuracy: 0.9382
# Epoch 2 / 10:
#   Training Accuracy: 0.9424
#   Training Cost: 196.1669
#   Eval Accuracy: 0.9511
# Epoch 3 / 10:
#   Training Accuracy: 0.9544
#   Training Cost: 155.7921
#   Eval Accuracy: 0.9549
# Epoch 4 / 10:
#   Training Accuracy: 0.9603
#   Training Cost: 135.4742
#   Eval Accuracy: 0.9588
# Epoch 5 / 10:
#   Training Accuracy: 0.9654
#   Training Cost: 119.9111
#   Eval Accuracy: 0.9589
# Epoch 6 / 10:
#   Training Accuracy: 0.9676
#   Training Cost: 110.5357
#   Eval Accuracy: 0.9634
# Epoch 7 / 10:
#   Training Accuracy: 0.9705
#   Training Cost: 99.9470
#   Eval Accuracy: 0.9633
# Epoch 8 / 10:
#   Training Accuracy: 0.9717
#   Training Cost: 93.6982
#   Eval Accuracy: 0.9606
# Epoch 9 / 10:
#   Training Accuracy: 0.9737
#   Training Cost: 87.3280
#   Eval Accuracy: 0.9643
# Epoch 10 / 10:
#   Training Accuracy: 0.9752
#   Training Cost: 82.3459
#   Eval Accuracy: 0.9649

# %% [markdown]
# Now run again with the increased learning rate. Which accuracy can you achieve now? How did the accuracies change while training, compared to the lower learning rate?
#
# **Note:** Make sure, to reinitialize your model's parameters. Don't continue on the already trained parameters.

# %%
higher_learning_rate = 3

model = Sequential(Linear(784,linear_units), Sigmoid(), Linear(linear_units,10))
params = model.parameters()
optim = SGD(params, higher_learning_rate, momentum)
loss_fn = CrossEntropyLoss()

train(model, loss_fn, optim, x_train, y_train, x_val, y_val, num_epochs, batch_size);
# Out:
# Epoch 1 / 10:
#   Training Accuracy: 0.0991
#   Training Cost: 2456.0508
#   Eval Accuracy: 0.0991
# Epoch 2 / 10:
#   Training Accuracy: 0.1020
#   Training Cost: 2451.5940
#   Eval Accuracy: 0.0915
# Epoch 3 / 10:
#   Training Accuracy: 0.0981
#   Training Cost: 2474.2669
#   Eval Accuracy: 0.0967
# Epoch 4 / 10:
#   Training Accuracy: 0.0991
#   Training Cost: 2460.3781
#   Eval Accuracy: 0.1009
# Epoch 5 / 10:
#   Training Accuracy: 0.1004
#   Training Cost: 2456.9169
#   Eval Accuracy: 0.1090
# Epoch 6 / 10:
#   Training Accuracy: 0.1018
#   Training Cost: 2456.6373
#   Eval Accuracy: 0.0915
# Epoch 7 / 10:
#   Training Accuracy: 0.1023
#   Training Cost: 2451.2514
#   Eval Accuracy: 0.1090
# Epoch 8 / 10:
#   Training Accuracy: 0.1017
#   Training Cost: 2452.2222
#   Eval Accuracy: 0.0990
# Epoch 9 / 10:
#   Training Accuracy: 0.1010
#   Training Cost: 2450.6480
#   Eval Accuracy: 0.1064
# Epoch 10 / 10:
#   Training Accuracy: 0.1028
#   Training Cost: 2446.1725
#   Eval Accuracy: 0.0967

# %% [markdown]
# Train only a subset of 1000 training samples, but for 300 epochs.
# Plot the costs & accuracies for both training and validation.
#
# How do the accuracies change compared to the previous runs?
# How is this plot related to the term 'overfitting'?

# %%
num_train_samples = 1000
num_epochs = 300

model = Sequential(Linear(784,linear_units), Sigmoid(), Linear(linear_units,10))
params = model.parameters()
optim = SGD(params, learning_rate, momentum)
loss_fn = CrossEntropyLoss()

x_mini = x_train[:num_train_samples]
y_mini = y_train[:num_train_samples]

tc, ta, vc, va = train(model, loss_fn, optim, 
                       x_mini, y_mini, x_val, y_val, 
                       num_epochs, batch_size);
# Out:
# Epoch 1 / 300:
#   Training Accuracy: 0.1090
#   Training Cost: 46.4530
#   Eval Accuracy: 0.2024
# Epoch 2 / 300:
#   Training Accuracy: 0.1310
#   Training Cost: 45.9548
#   Eval Accuracy: 0.1531
# Epoch 3 / 300:
#   Training Accuracy: 0.2960
#   Training Cost: 40.8619
#   Eval Accuracy: 0.4013
# Epoch 4 / 300:
#   Training Accuracy: 0.5320
#   Training Cost: 29.3133
#   Eval Accuracy: 0.6191
# Epoch 5 / 300:
#   Training Accuracy: 0.6860
#   Training Cost: 20.2123
#   Eval Accuracy: 0.7393
# Epoch 6 / 300:
#   Training Accuracy: 0.8020
#   Training Cost: 15.1603
#   Eval Accuracy: 0.7940
# Epoch 7 / 300:
#   Training Accuracy: 0.8620
#   Training Cost: 11.8382
#   Eval Accuracy: 0.8201
# Epoch 8 / 300:
#   Training Accuracy: 0.8850
#   Training Cost: 9.4300
#   Eval Accuracy: 0.8352
# Epoch 9 / 300:
#   Training Accuracy: 0.9070
#   Training Cost: 7.7272
#   Eval Accuracy: 0.8632
# Epoch 10 / 300:
#   Training Accuracy: 0.9150
#   Training Cost: 6.6527
#   Eval Accuracy: 0.8652
# Epoch 11 / 300:
#   Training Accuracy: 0.9210
#   Training Cost: 5.7759
#   Eval Accuracy: 0.8618
# Epoch 12 / 300:
#   Training Accuracy: 0.9380
#   Training Cost: 5.1395
#   Eval Accuracy: 0.8703
# Epoch 13 / 300:
#   Training Accuracy: 0.9490
#   Training Cost: 4.5178
#   Eval Accuracy: 0.8698
# Epoch 14 / 300:
#   Training Accuracy: 0.9520
#   Training Cost: 4.1226
#   Eval Accuracy: 0.8664
# Epoch 15 / 300:
#   Training Accuracy: 0.9560
#   Training Cost: 3.6772
#   Eval Accuracy: 0.8754
# Epoch 16 / 300:
#   Training Accuracy: 0.9720
#   Training Cost: 3.2920
#   Eval Accuracy: 0.8711
# Epoch 17 / 300:
#   Training Accuracy: 0.9740
#   Training Cost: 2.9381
#   Eval Accuracy: 0.8776
# Epoch 18 / 300:
#   Training Accuracy: 0.9790
#   Training Cost: 2.6054
#   Eval Accuracy: 0.8752
# Epoch 19 / 300:
#   Training Accuracy: 0.9790
#   Training Cost: 2.3967
#   Eval Accuracy: 0.8735
# Epoch 20 / 300:
#   Training Accuracy: 0.9870
#   Training Cost: 2.2138
#   Eval Accuracy: 0.8730
# Epoch 21 / 300:
#   Training Accuracy: 0.9910
#   Training Cost: 1.9687
#   Eval Accuracy: 0.8788
# Epoch 22 / 300:
#   Training Accuracy: 0.9900
#   Training Cost: 1.8161
#   Eval Accuracy: 0.8776
# Epoch 23 / 300:
#   Training Accuracy: 0.9940
#   Training Cost: 1.6966
#   Eval Accuracy: 0.8794
# Epoch 24 / 300:
#   Training Accuracy: 0.9950
#   Training Cost: 1.5566
#   Eval Accuracy: 0.8744
# Epoch 25 / 300:
#   Training Accuracy: 0.9950
#   Training Cost: 1.4290
#   Eval Accuracy: 0.8766
# Epoch 26 / 300:
#   Training Accuracy: 0.9960
#   Training Cost: 1.3347
#   Eval Accuracy: 0.8779
# Epoch 27 / 300:
#   Training Accuracy: 0.9970
#   Training Cost: 1.2441
#   Eval Accuracy: 0.8785
# Epoch 28 / 300:
#   Training Accuracy: 0.9980
#   Training Cost: 1.1580
#   Eval Accuracy: 0.8789
# Epoch 29 / 300:
#   Training Accuracy: 0.9980
#   Training Cost: 1.0926
#   Eval Accuracy: 0.8767
# Epoch 30 / 300:
#   Training Accuracy: 0.9980
#   Training Cost: 1.0093
#   Eval Accuracy: 0.8783
# Epoch 31 / 300:
#   Training Accuracy: 0.9980
#   Training Cost: 0.9438
#   Eval Accuracy: 0.8784
# Epoch 32 / 300:
#   Training Accuracy: 0.9980
#   Training Cost: 0.8831
#   Eval Accuracy: 0.8788
# Epoch 33 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.8378
#   Eval Accuracy: 0.8778
# Epoch 34 / 300:
#   Training Accuracy: 0.9980
#   Training Cost: 0.7818
#   Eval Accuracy: 0.8784
# Epoch 35 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.7394
#   Eval Accuracy: 0.8790
# Epoch 36 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.7072
#   Eval Accuracy: 0.8785
# Epoch 37 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.6692
#   Eval Accuracy: 0.8791
# Epoch 38 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.6354
#   Eval Accuracy: 0.8782
# Epoch 39 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.6075
#   Eval Accuracy: 0.8792
# Epoch 40 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.5835
#   Eval Accuracy: 0.8795
# Epoch 41 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.5556
#   Eval Accuracy: 0.8787
# Epoch 42 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.5308
#   Eval Accuracy: 0.8785
# Epoch 43 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.5118
#   Eval Accuracy: 0.8789
# Epoch 44 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.4896
#   Eval Accuracy: 0.8791
# Epoch 45 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.4728
#   Eval Accuracy: 0.8787
# Epoch 46 / 300:
#   Training Accuracy: 0.9990
#   Training Cost: 0.4552
#   Eval Accuracy: 0.8796
# Epoch 47 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.4378
#   Eval Accuracy: 0.8795
# Epoch 48 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.4244
#   Eval Accuracy: 0.8794
# Epoch 49 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.4066
#   Eval Accuracy: 0.8788
# Epoch 50 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.3949
#   Eval Accuracy: 0.8784
# Epoch 51 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.3802
#   Eval Accuracy: 0.8800
# Epoch 52 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.3660
#   Eval Accuracy: 0.8797
# Epoch 53 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.3587
#   Eval Accuracy: 0.8794
# Epoch 54 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.3432
#   Eval Accuracy: 0.8797
# Epoch 55 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.3321
#   Eval Accuracy: 0.8793
# Epoch 56 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.3211
#   Eval Accuracy: 0.8792
# Epoch 57 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.3135
#   Eval Accuracy: 0.8797
# Epoch 58 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.3018
#   Eval Accuracy: 0.8793
# Epoch 59 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2959
#   Eval Accuracy: 0.8800
# Epoch 60 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2848
#   Eval Accuracy: 0.8792
# Epoch 61 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2783
#   Eval Accuracy: 0.8795
# Epoch 62 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2720
#   Eval Accuracy: 0.8793
# Epoch 63 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2631
#   Eval Accuracy: 0.8790
# Epoch 64 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2559
#   Eval Accuracy: 0.8795
# Epoch 65 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2507
#   Eval Accuracy: 0.8795
# Epoch 66 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2429
#   Eval Accuracy: 0.8797
# Epoch 67 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2375
#   Eval Accuracy: 0.8793
# Epoch 68 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2341
#   Eval Accuracy: 0.8788
# Epoch 69 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2279
#   Eval Accuracy: 0.8796
# Epoch 70 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2230
#   Eval Accuracy: 0.8790
# Epoch 71 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2179
#   Eval Accuracy: 0.8793
# Epoch 72 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2124
#   Eval Accuracy: 0.8789
# Epoch 73 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2084
#   Eval Accuracy: 0.8797
# Epoch 74 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2045
#   Eval Accuracy: 0.8795
# Epoch 75 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.2005
#   Eval Accuracy: 0.8791
# Epoch 76 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1968
#   Eval Accuracy: 0.8798
# Epoch 77 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1918
#   Eval Accuracy: 0.8791
# Epoch 78 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1887
#   Eval Accuracy: 0.8791
# Epoch 79 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1859
#   Eval Accuracy: 0.8795
# Epoch 80 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1822
#   Eval Accuracy: 0.8795
# Epoch 81 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1787
#   Eval Accuracy: 0.8799
# Epoch 82 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1748
#   Eval Accuracy: 0.8792
# Epoch 83 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1722
#   Eval Accuracy: 0.8798
# Epoch 84 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1690
#   Eval Accuracy: 0.8796
# Epoch 85 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1664
#   Eval Accuracy: 0.8797
# Epoch 86 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1639
#   Eval Accuracy: 0.8792
# Epoch 87 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1616
#   Eval Accuracy: 0.8799
# Epoch 88 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1584
#   Eval Accuracy: 0.8797
# Epoch 89 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1560
#   Eval Accuracy: 0.8796
# Epoch 90 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1533
#   Eval Accuracy: 0.8799
# Epoch 91 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1516
#   Eval Accuracy: 0.8787
# Epoch 92 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1493
#   Eval Accuracy: 0.8795
# Epoch 93 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1464
#   Eval Accuracy: 0.8796
# Epoch 94 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1444
#   Eval Accuracy: 0.8802
# Epoch 95 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1428
#   Eval Accuracy: 0.8789
# Epoch 96 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1407
#   Eval Accuracy: 0.8800
# Epoch 97 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1382
#   Eval Accuracy: 0.8796
# Epoch 98 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1365
#   Eval Accuracy: 0.8788
# Epoch 99 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1341
#   Eval Accuracy: 0.8797
# Epoch 100 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1325
#   Eval Accuracy: 0.8798
# Epoch 101 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1303
#   Eval Accuracy: 0.8794
# Epoch 102 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1284
#   Eval Accuracy: 0.8796
# Epoch 103 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1272
#   Eval Accuracy: 0.8797
# Epoch 104 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1252
#   Eval Accuracy: 0.8798
# Epoch 105 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1237
#   Eval Accuracy: 0.8793
# Epoch 106 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1219
#   Eval Accuracy: 0.8795
# Epoch 107 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1203
#   Eval Accuracy: 0.8801
# Epoch 108 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1190
#   Eval Accuracy: 0.8801
# Epoch 109 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1172
#   Eval Accuracy: 0.8791
# Epoch 110 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1161
#   Eval Accuracy: 0.8794
# Epoch 111 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1146
#   Eval Accuracy: 0.8797
# Epoch 112 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1135
#   Eval Accuracy: 0.8799
# Epoch 113 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1119
#   Eval Accuracy: 0.8797
# Epoch 114 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1108
#   Eval Accuracy: 0.8791
# Epoch 115 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1092
#   Eval Accuracy: 0.8793
# Epoch 116 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1080
#   Eval Accuracy: 0.8792
# Epoch 117 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1067
#   Eval Accuracy: 0.8795
# Epoch 118 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1057
#   Eval Accuracy: 0.8796
# Epoch 119 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1044
#   Eval Accuracy: 0.8790
# Epoch 120 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1031
#   Eval Accuracy: 0.8793
# Epoch 121 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1019
#   Eval Accuracy: 0.8796
# Epoch 122 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.1011
#   Eval Accuracy: 0.8789
# Epoch 123 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0998
#   Eval Accuracy: 0.8796
# Epoch 124 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0988
#   Eval Accuracy: 0.8798
# Epoch 125 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0977
#   Eval Accuracy: 0.8792
# Epoch 126 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0968
#   Eval Accuracy: 0.8790
# Epoch 127 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0957
#   Eval Accuracy: 0.8796
# Epoch 128 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0947
#   Eval Accuracy: 0.8794
# Epoch 129 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0936
#   Eval Accuracy: 0.8796
# Epoch 130 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0928
#   Eval Accuracy: 0.8790
# Epoch 131 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0916
#   Eval Accuracy: 0.8794
# Epoch 132 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0909
#   Eval Accuracy: 0.8791
# Epoch 133 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0901
#   Eval Accuracy: 0.8795
# Epoch 134 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0890
#   Eval Accuracy: 0.8794
# Epoch 135 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0882
#   Eval Accuracy: 0.8793
# Epoch 136 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0875
#   Eval Accuracy: 0.8795
# Epoch 137 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0865
#   Eval Accuracy: 0.8798
# Epoch 138 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0858
#   Eval Accuracy: 0.8796
# Epoch 139 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0849
#   Eval Accuracy: 0.8793
# Epoch 140 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0842
#   Eval Accuracy: 0.8793
# Epoch 141 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0833
#   Eval Accuracy: 0.8795
# Epoch 142 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0826
#   Eval Accuracy: 0.8793
# Epoch 143 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0819
#   Eval Accuracy: 0.8794
# Epoch 144 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0811
#   Eval Accuracy: 0.8795
# Epoch 145 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0803
#   Eval Accuracy: 0.8794
# Epoch 146 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0797
#   Eval Accuracy: 0.8796
# Epoch 147 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0789
#   Eval Accuracy: 0.8793
# Epoch 148 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0783
#   Eval Accuracy: 0.8795
# Epoch 149 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0776
#   Eval Accuracy: 0.8794
# Epoch 150 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0771
#   Eval Accuracy: 0.8796
# Epoch 151 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0763
#   Eval Accuracy: 0.8799
# Epoch 152 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0757
#   Eval Accuracy: 0.8795
# Epoch 153 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0750
#   Eval Accuracy: 0.8793
# Epoch 154 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0745
#   Eval Accuracy: 0.8793
# Epoch 155 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0737
#   Eval Accuracy: 0.8795
# Epoch 156 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0732
#   Eval Accuracy: 0.8798
# Epoch 157 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0726
#   Eval Accuracy: 0.8794
# Epoch 158 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0719
#   Eval Accuracy: 0.8792
# Epoch 159 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0714
#   Eval Accuracy: 0.8793
# Epoch 160 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0709
#   Eval Accuracy: 0.8793
# Epoch 161 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0705
#   Eval Accuracy: 0.8803
# Epoch 162 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0697
#   Eval Accuracy: 0.8794
# Epoch 163 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0691
#   Eval Accuracy: 0.8794
# Epoch 164 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0686
#   Eval Accuracy: 0.8794
# Epoch 165 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0682
#   Eval Accuracy: 0.8794
# Epoch 166 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0677
#   Eval Accuracy: 0.8795
# Epoch 167 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0671
#   Eval Accuracy: 0.8799
# Epoch 168 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0666
#   Eval Accuracy: 0.8794
# Epoch 169 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0662
#   Eval Accuracy: 0.8797
# Epoch 170 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0656
#   Eval Accuracy: 0.8799
# Epoch 171 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0651
#   Eval Accuracy: 0.8795
# Epoch 172 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0646
#   Eval Accuracy: 0.8793
# Epoch 173 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0642
#   Eval Accuracy: 0.8797
# Epoch 174 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0638
#   Eval Accuracy: 0.8792
# Epoch 175 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0632
#   Eval Accuracy: 0.8795
# Epoch 176 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0628
#   Eval Accuracy: 0.8795
# Epoch 177 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0624
#   Eval Accuracy: 0.8795
# Epoch 178 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0619
#   Eval Accuracy: 0.8798
# Epoch 179 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0615
#   Eval Accuracy: 0.8802
# Epoch 180 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0610
#   Eval Accuracy: 0.8799
# Epoch 181 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0606
#   Eval Accuracy: 0.8797
# Epoch 182 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0603
#   Eval Accuracy: 0.8798
# Epoch 183 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0598
#   Eval Accuracy: 0.8798
# Epoch 184 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0594
#   Eval Accuracy: 0.8800
# Epoch 185 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0590
#   Eval Accuracy: 0.8796
# Epoch 186 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0586
#   Eval Accuracy: 0.8799
# Epoch 187 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0582
#   Eval Accuracy: 0.8798
# Epoch 188 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0578
#   Eval Accuracy: 0.8798
# Epoch 189 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0575
#   Eval Accuracy: 0.8798
# Epoch 190 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0570
#   Eval Accuracy: 0.8800
# Epoch 191 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0567
#   Eval Accuracy: 0.8796
# Epoch 192 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0563
#   Eval Accuracy: 0.8800
# Epoch 193 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0560
#   Eval Accuracy: 0.8799
# Epoch 194 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0555
#   Eval Accuracy: 0.8797
# Epoch 195 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0553
#   Eval Accuracy: 0.8799
# Epoch 196 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0549
#   Eval Accuracy: 0.8799
# Epoch 197 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0545
#   Eval Accuracy: 0.8797
# Epoch 198 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0541
#   Eval Accuracy: 0.8801
# Epoch 199 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0539
#   Eval Accuracy: 0.8801
# Epoch 200 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0536
#   Eval Accuracy: 0.8799
# Epoch 201 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0532
#   Eval Accuracy: 0.8796
# Epoch 202 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0529
#   Eval Accuracy: 0.8798
# Epoch 203 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0525
#   Eval Accuracy: 0.8796
# Epoch 204 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0522
#   Eval Accuracy: 0.8796
# Epoch 205 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0519
#   Eval Accuracy: 0.8799
# Epoch 206 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0516
#   Eval Accuracy: 0.8796
# Epoch 207 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0513
#   Eval Accuracy: 0.8798
# Epoch 208 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0510
#   Eval Accuracy: 0.8799
# Epoch 209 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0507
#   Eval Accuracy: 0.8798
# Epoch 210 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0504
#   Eval Accuracy: 0.8797
# Epoch 211 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0501
#   Eval Accuracy: 0.8798
# Epoch 212 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0498
#   Eval Accuracy: 0.8800
# Epoch 213 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0495
#   Eval Accuracy: 0.8799
# Epoch 214 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0492
#   Eval Accuracy: 0.8800
# Epoch 215 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0489
#   Eval Accuracy: 0.8799
# Epoch 216 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0487
#   Eval Accuracy: 0.8798
# Epoch 217 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0484
#   Eval Accuracy: 0.8797
# Epoch 218 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0481
#   Eval Accuracy: 0.8797
# Epoch 219 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0479
#   Eval Accuracy: 0.8800
# Epoch 220 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0476
#   Eval Accuracy: 0.8798
# Epoch 221 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0473
#   Eval Accuracy: 0.8801
# Epoch 222 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0471
#   Eval Accuracy: 0.8797
# Epoch 223 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0468
#   Eval Accuracy: 0.8798
# Epoch 224 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0465
#   Eval Accuracy: 0.8800
# Epoch 225 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0463
#   Eval Accuracy: 0.8796
# Epoch 226 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0460
#   Eval Accuracy: 0.8798
# Epoch 227 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0458
#   Eval Accuracy: 0.8799
# Epoch 228 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0455
#   Eval Accuracy: 0.8800
# Epoch 229 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0453
#   Eval Accuracy: 0.8800
# Epoch 230 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0451
#   Eval Accuracy: 0.8797
# Epoch 231 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0448
#   Eval Accuracy: 0.8800
# Epoch 232 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0446
#   Eval Accuracy: 0.8800
# Epoch 233 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0444
#   Eval Accuracy: 0.8799
# Epoch 234 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0442
#   Eval Accuracy: 0.8798
# Epoch 235 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0439
#   Eval Accuracy: 0.8798
# Epoch 236 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0437
#   Eval Accuracy: 0.8799
# Epoch 237 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0434
#   Eval Accuracy: 0.8797
# Epoch 238 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0432
#   Eval Accuracy: 0.8800
# Epoch 239 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0430
#   Eval Accuracy: 0.8801
# Epoch 240 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0428
#   Eval Accuracy: 0.8798
# Epoch 241 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0426
#   Eval Accuracy: 0.8799
# Epoch 242 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0424
#   Eval Accuracy: 0.8799
# Epoch 243 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0422
#   Eval Accuracy: 0.8799
# Epoch 244 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0419
#   Eval Accuracy: 0.8799
# Epoch 245 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0417
#   Eval Accuracy: 0.8801
# Epoch 246 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0416
#   Eval Accuracy: 0.8800
# Epoch 247 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0413
#   Eval Accuracy: 0.8801
# Epoch 248 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0411
#   Eval Accuracy: 0.8804
# Epoch 249 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0409
#   Eval Accuracy: 0.8798
# Epoch 250 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0407
#   Eval Accuracy: 0.8803
# Epoch 251 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0405
#   Eval Accuracy: 0.8800
# Epoch 252 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0403
#   Eval Accuracy: 0.8800
# Epoch 253 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0401
#   Eval Accuracy: 0.8798
# Epoch 254 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0399
#   Eval Accuracy: 0.8802
# Epoch 255 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0398
#   Eval Accuracy: 0.8801
# Epoch 256 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0396
#   Eval Accuracy: 0.8801
# Epoch 257 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0394
#   Eval Accuracy: 0.8802
# Epoch 258 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0393
#   Eval Accuracy: 0.8802
# Epoch 259 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0390
#   Eval Accuracy: 0.8802
# Epoch 260 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0389
#   Eval Accuracy: 0.8806
# Epoch 261 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0387
#   Eval Accuracy: 0.8803
# Epoch 262 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0385
#   Eval Accuracy: 0.8802
# Epoch 263 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0383
#   Eval Accuracy: 0.8800
# Epoch 264 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0382
#   Eval Accuracy: 0.8806
# Epoch 265 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0380
#   Eval Accuracy: 0.8799
# Epoch 266 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0378
#   Eval Accuracy: 0.8802
# Epoch 267 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0376
#   Eval Accuracy: 0.8807
# Epoch 268 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0374
#   Eval Accuracy: 0.8801
# Epoch 269 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0373
#   Eval Accuracy: 0.8801
# Epoch 270 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0371
#   Eval Accuracy: 0.8801
# Epoch 271 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0369
#   Eval Accuracy: 0.8801
# Epoch 272 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0368
#   Eval Accuracy: 0.8801
# Epoch 273 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0366
#   Eval Accuracy: 0.8803
# Epoch 274 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0365
#   Eval Accuracy: 0.8800
# Epoch 275 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0363
#   Eval Accuracy: 0.8801
# Epoch 276 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0362
#   Eval Accuracy: 0.8801
# Epoch 277 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0360
#   Eval Accuracy: 0.8807
# Epoch 278 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0358
#   Eval Accuracy: 0.8805
# Epoch 279 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0357
#   Eval Accuracy: 0.8802
# Epoch 280 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0355
#   Eval Accuracy: 0.8804
# Epoch 281 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0354
#   Eval Accuracy: 0.8802
# Epoch 282 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0352
#   Eval Accuracy: 0.8801
# Epoch 283 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0351
#   Eval Accuracy: 0.8807
# Epoch 284 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0349
#   Eval Accuracy: 0.8806
# Epoch 285 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0348
#   Eval Accuracy: 0.8804
# Epoch 286 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0347
#   Eval Accuracy: 0.8801
# Epoch 287 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0345
#   Eval Accuracy: 0.8803
# Epoch 288 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0344
#   Eval Accuracy: 0.8806
# Epoch 289 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0342
#   Eval Accuracy: 0.8802
# Epoch 290 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0341
#   Eval Accuracy: 0.8800
# Epoch 291 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0339
#   Eval Accuracy: 0.8801
# Epoch 292 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0338
#   Eval Accuracy: 0.8807
# Epoch 293 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0337
#   Eval Accuracy: 0.8802
# Epoch 294 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0335
#   Eval Accuracy: 0.8806
# Epoch 295 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0334
#   Eval Accuracy: 0.8807
# Epoch 296 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0333
#   Eval Accuracy: 0.8807
# Epoch 297 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0331
#   Eval Accuracy: 0.8807
# Epoch 298 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0330
#   Eval Accuracy: 0.8804
# Epoch 299 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0328
#   Eval Accuracy: 0.8804
# Epoch 300 / 300:
#   Training Accuracy: 1.0000
#   Training Cost: 0.0327
#   Eval Accuracy: 0.8802

# %%
plt.figure(1)
plt.plot(tc, label='training')
plt.plot(vc, label='validation')
plt.legend(loc='best')
plt.ylabel('cost')
plt.xlabel('epochs')
plt.grid(True)

plt.show()

plt.figure(2)
plt.plot(ta, label='training')
plt.plot(va, label='validation')
plt.legend(loc='best')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.grid(True)

# %% [markdown]
# ** Your feedback on exercise 2.3: **
