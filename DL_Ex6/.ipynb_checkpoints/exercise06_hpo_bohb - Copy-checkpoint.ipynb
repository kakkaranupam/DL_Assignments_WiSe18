# %% [markdown]
# # Sixth Exercise (HPO)
#
# This exercise focuses on hyperparameter optimization with neural networks.
#
# We will
# - define hyperparameter-configuration search-spaces
# - train deep learning models with various hyper parameters
# - use random search as a basic hyperparameter optimizer
# - use BOHB as an advanced hyperparameter optimizer
#
# It's in the nature of hyperparameter optimization, that you'll have to train a lot of models.
# Therefore execution time will be longer in this exercise, running the completed notebook takes about 30 minutes on a tutor's 3 year old laptop.

# %% [markdown]
# #### Install HpBandster and torchvision
#
# You need to install two more python packages for this exercise.
#
# - [torchvision](https://pytorch.org/docs/stable/torchvision/) provides utility methods for pytorch.
# - [HpBandSter](https://github.com/automl/HpBandSter) is a fast, parallel implementation of several hyperparameter optimizers.
#    We can define even complex hyperparameter search spaces with [ConfigSpace](https://github.com/automl/ConfigSpace), which comes along HpBandSter as dependency.
#
#
# Install with anaconda/conda
# ```
# conda install torchvision
# conda install hpbandster
# ```
#
# or with plain python
# ```
# pip3 install torchvision
# pip3 install hpbandster
# ```

# %%
import os
from typing import Tuple, List

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import torchvision
import torchvision.transforms as transforms

import ConfigSpace as CS
import ConfigSpace.hyperparameters as CSH

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


def load_mnist_minibatched(batch_size: int, n_train: int = 8192, n_valid: int = 1024,
                           valid_test_batch_size: int = 1024) -> Tuple[DataLoader, DataLoader, DataLoader]:
    train_dataset = torchvision.datasets.MNIST(
        root='../data', train=True, transform=transforms.ToTensor(), download=True)
    test_dataset = torchvision.datasets.MNIST(
        root='../data', train=False, transform=transforms.ToTensor())

    train_sampler = SubsetRandomSampler(range(n_train))
    validation_sampler = SubsetRandomSampler(range(n_train, n_train+n_valid))

    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, sampler=train_sampler)
    validation_loader = DataLoader(dataset=train_dataset, batch_size=valid_test_batch_size,
                                   sampler=validation_sampler)
    test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=valid_test_batch_size, 
                                              shuffle=False)
    return train_loader, validation_loader, test_loader


def evaluate_accuracy(model: nn.Module, data_loader: DataLoader) -> float:
    model.eval()
    correct = 0
    with torch.no_grad():
        for x, y in data_loader:
            output = model(x)
            # get the index of the max log-probability
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(y.view_as(pred)).sum().item()
    accuracy = correct / len(data_loader.sampler)
    return(accuracy)

# %% [markdown]
# ## Random Search
#
# Here we get hands on hyperparameter optimization using random search.
#
# ### Model and Hyperparameter Space
#
# First we define a configurable model and a hyperparameter space. You learn how to use *ConfigSpace* to define the hyperparameters, by looking at [this example](https://automl.github.io/SMAC3/stable/quickstart.html#using-smac-in-python-svm).
#
# **Task:** Complete the functions as described in the docstrings.
#
# **Hint:** The `CS.GreaterThanCondition(conditioned_hyperparameter, lefthand_side, righthand_side)` method might be useful.

# %%
from collections import OrderedDict

class Flatten(nn.Module):
    def forward(self, input):
        self.input_shape = input.shape
        return input.view(input.size(0), -1)
    
def get_conv_model(num_filters_per_layer: List[int]) -> nn.Module:
    """Builds a deep convolutional model with various number of convolution
       layers for MNIST input using pytorch.
    
    for each element in num_filters_per_layer:
        convolution (conv_kernel_size, num_filters, stride=1, padding=0)
        relu
        max pool    (pool_kernel_size, stride=None)
    linear
    log softmax
    """
    assert len(num_filters_per_layer) > 0, "len(num_filters_per_layer) should be greater than 0"
    pool_kernel_size = 2
    conv_kernel_size = 3
    
    # (28 - 3 + 0)/1 + 1 = 26
    # (26 - 2)/2 + 1 = 13
    # (13 - 3 + 0)/1 + 1 = 11
    # (11 - 2)/2 + 1 = 5
    
    # START TODO ################
    if len(num_filters_per_layer) == 1:
        model = nn.Sequential(nn.Conv2d(in_channels=1,
                                     out_channels=num_filters_per_layer[0],
                                     kernel_size=conv_kernel_size,
                                     stride=1,
                                     padding=0),
                           nn.ReLU(),
                           nn.MaxPool2d(kernel_size=pool_kernel_size, stride=2, padding=0),
                           Flatten(),
                           nn.Linear(num_filters_per_layer[0] * 13 * 13, 10),
                           nn.LogSoftmax())
    
    else:
        model = nn.Sequential(nn.Conv2d(in_channels=1,
                                     out_channels=num_filters_per_layer[0],
                                     kernel_size=conv_kernel_size,
                                     stride=1,
                                     padding=0),
                           nn.ReLU(),
                           nn.MaxPool2d(kernel_size=pool_kernel_size, stride=2, padding=0),
                           nn.Conv2d(in_channels=num_filters_per_layer[0],
                                     out_channels=num_filters_per_layer[1],
                                     kernel_size=conv_kernel_size,
                                     stride=1,
                                     padding=0),
                           nn.ReLU(),
                           nn.MaxPool2d(kernel_size=pool_kernel_size, stride=2, padding=0),
                           Flatten(),
                           nn.Linear(num_filters_per_layer[1] * 5 * 5, 10),
                           nn.LogSoftmax()) 
    
    
    return model
    # End TODO ################


def get_configspace() -> CS.ConfigurationSpace:
    """ Define a conditional hyperparameter search-space.
    
    hyperparameters:
      lr              from 1e-6 to 1e-0 (log, float)
      num_filters_1   from    2 to    8 (int)
      num_filters_2   from    2 to    8 (int)
      num_conv_layers from    1 to    2 (int)
    
    conditions: 
      include num_filters_2 only if num_conv_layers > 1
    """
    cs = CS.ConfigurationSpace()
    # START TODO ################
    lr = CSH.UniformFloatHyperparameter('lr', lower=1e-06, upper=1e-0, default_value='0.1', log=True)
    num_filters_1 = CSH.UniformIntegerHyperparameter('num_filters_1',lower=2,upper=8,log=False)
    num_filters_2 = CSH.UniformIntegerHyperparameter('num_filters_2',lower=2,upper=8,log=False)
    num_conv_layers = CSH.UniformIntegerHyperparameter('num_conv_layers',lower=1,upper=2,log=False)
    cs.add_hyperparameters([lr])
    cs.add_hyperparameters([num_filters_1])
    cs.add_hyperparameters([num_filters_2])
    cs.add_hyperparameters([num_conv_layers])
    cs.add_condition(CS.GreaterThanCondition(num_filters_2,num_conv_layers,1))
    
    # End TODO ################
    return cs

# %% [markdown]
# ### Run model with configuration
#
# A single sample from your hyperparameter space is a *Configuration*. You can use the configuration similar to a dictionary, it supports *config.keys(), config.values(), value = config[key], key in config, …* .
# You can iterate a *DataLoader* to access (data, label) batches.
#
# **Note:** If a condition isn't met, the conditional hyperparameter isn't included in the configuration.
#
# **Task:** Complete the function to run a model like defined by the configuration. The function should return the model and the *validation error* for each epoch. You can use *evaluate_accuracy* (defined above), don't forget to switch between train and eval mode.

# %%
def run_conv_model(config: CS.Configuration, epochs: int, train_loader: DataLoader,
                   validation_loader: DataLoader) -> Tuple[nn.Module, List[float]]:    
    """ Run and evaluate a model from get_conv_model with NLLLoss and SGD.
    """
    # START TODO ################
    # retrieve the number of filters from the config and create the model
    print(config)
    num_filters_1= config['num_filters_1']
    num_filter_per_layer=[]
    num_filter_per_layer.append(num_filters_1)
   
    num_conv_layers= config['num_conv_layers']
    if num_conv_layers >1:
        num_filters_2= config['num_filters_2']
        num_filter_per_layer.append(num_filters_2)
            

    
    model = get_conv_model(num_filter_per_layer)
    
    
    
    # define loss and optimizer
    loss_fnc=nn.NLLLoss()
    optimizer = torch.optim.SGD(model.parameters(), lr = config['lr'])
    
    
    # train the model for `epochs` and save the validation error for each epoch in
    # val_errors
    val_errors = []
    #model.train_loader = train_loader
    #model.validation_loader = validation_loader
    
    
    for epoch in range (1,epochs):
        model.train()
        for idx,data in enumerate(train_loader):
            inputs, labels = data
            #print(inputs)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss= loss_fnc(outputs,labels)
            loss.backward()
            optimizer.step()
            
        model.eval()
        error= 1-evaluate_accuracy(model,validation_loader)
        val_errors.append(error)
        print("epoch :",epoch,"validation error :", error )
       
            
    # End TODO ################
    return model, val_errors

# %% [markdown]
# Now let's run models with various, random hyperparameter configurations. Don't forget to store all the configuration and validation errors for further evaluation.
#
# **Tipp:** *ConfigSpace* objects have a *.sample_configuration()* function to sample a random configuration.
#
# **Task:** Run *n_random_samples* models for *n_epochs* and store the tuple `(model, config, val_errors)` in `results`.

# %%
n_random_samples = 18
n_epochs = 9
cs = get_configspace()
train_loader, validation_loader, _ = load_mnist_minibatched(batch_size=32, n_train=4096, n_valid=512)
results=[]

# START TODO ################
for r in range (n_random_samples):
    config=cs.sample_configuration()
    model, valid_error=run_conv_model(config,n_epochs,train_loader,validation_loader)
    results.append((model,config,valid_error))


# End TODO ################
# Out:
# Configuration:
#   lr, Value: 9.675782323674071e-06
#   num_conv_layers, Value: 2
#   num_filters_1, Value: 7
#   num_filters_2, Value: 3
# C:\Users\MYPC\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# epoch : 1 validation error : 0.8046875
# epoch : 2 validation error : 0.8046875
# epoch : 3 validation error : 0.8046875
# epoch : 4 validation error : 0.8046875
# epoch : 5 validation error : 0.8046875
# epoch : 6 validation error : 0.8046875
# epoch : 7 validation error : 0.8046875
# epoch : 8 validation error : 0.8046875
# Configuration:
#   lr, Value: 0.027771915414928017
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 5
#
# epoch : 1 validation error : 0.142578125
# epoch : 2 validation error : 0.12890625
# epoch : 3 validation error : 0.115234375
# epoch : 4 validation error : 0.12109375
# epoch : 5 validation error : 0.09375
# epoch : 6 validation error : 0.091796875
# epoch : 7 validation error : 0.115234375
# epoch : 8 validation error : 0.095703125
# Configuration:
#   lr, Value: 0.0003702169654967122
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 5
#
# epoch : 1 validation error : 0.87109375
# epoch : 2 validation error : 0.826171875
# epoch : 3 validation error : 0.794921875
# epoch : 4 validation error : 0.755859375
# epoch : 5 validation error : 0.70703125
# epoch : 6 validation error : 0.67578125
# epoch : 7 validation error : 0.638671875
# epoch : 8 validation error : 0.607421875
# Configuration:
#   lr, Value: 0.03664565013170859
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 7
#
# epoch : 1 validation error : 0.126953125
# epoch : 2 validation error : 0.111328125
# epoch : 3 validation error : 0.107421875
# epoch : 4 validation error : 0.111328125
# epoch : 5 validation error : 0.091796875
# epoch : 6 validation error : 0.08984375
# epoch : 7 validation error : 0.08203125
# epoch : 8 validation error : 0.080078125
# Configuration:
#   lr, Value: 0.04359130731821992
#   num_conv_layers, Value: 2
#   num_filters_1, Value: 4
#   num_filters_2, Value: 8
#
# epoch : 1 validation error : 0.263671875
# epoch : 2 validation error : 0.19921875
# epoch : 3 validation error : 0.109375
# epoch : 4 validation error : 0.13671875
# epoch : 5 validation error : 0.08984375
# epoch : 6 validation error : 0.0703125
# epoch : 7 validation error : 0.0703125
# epoch : 8 validation error : 0.068359375
# Configuration:
#   lr, Value: 7.393101389410029e-06
#   num_conv_layers, Value: 2
#   num_filters_1, Value: 2
#   num_filters_2, Value: 7
#
# epoch : 1 validation error : 0.896484375
# epoch : 2 validation error : 0.896484375
# epoch : 3 validation error : 0.896484375
# epoch : 4 validation error : 0.896484375
# epoch : 5 validation error : 0.896484375
# epoch : 6 validation error : 0.896484375
# epoch : 7 validation error : 0.896484375
# epoch : 8 validation error : 0.896484375
# Configuration:
#   lr, Value: 0.0018145991593835325
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 7
#
# epoch : 1 validation error : 0.6015625
# epoch : 2 validation error : 0.34375
# epoch : 3 validation error : 0.263671875
# epoch : 4 validation error : 0.21875
# epoch : 5 validation error : 0.21484375
# epoch : 6 validation error : 0.1875
# epoch : 7 validation error : 0.169921875
# epoch : 8 validation error : 0.158203125
# Configuration:
#   lr, Value: 1.494832755246159e-06
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 6
#
# epoch : 1 validation error : 0.951171875
# epoch : 2 validation error : 0.951171875
# epoch : 3 validation error : 0.951171875
# epoch : 4 validation error : 0.951171875
# epoch : 5 validation error : 0.951171875
# epoch : 6 validation error : 0.951171875
# epoch : 7 validation error : 0.951171875
# epoch : 8 validation error : 0.951171875
# Configuration:
#   lr, Value: 0.0004891775944444938
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 4
#
# epoch : 1 validation error : 0.83984375
# epoch : 2 validation error : 0.78125
# epoch : 3 validation error : 0.689453125
# epoch : 4 validation error : 0.564453125
# epoch : 5 validation error : 0.484375
# epoch : 6 validation error : 0.404296875
# epoch : 7 validation error : 0.357421875
# epoch : 8 validation error : 0.310546875
# Configuration:
#   lr, Value: 2.852234566976413e-05
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 3
#
# epoch : 1 validation error : 0.9609375
# epoch : 2 validation error : 0.9609375
# epoch : 3 validation error : 0.9609375
# epoch : 4 validation error : 0.9609375
# epoch : 5 validation error : 0.9609375
# epoch : 6 validation error : 0.9609375
# epoch : 7 validation error : 0.9609375
# epoch : 8 validation error : 0.9609375
# Configuration:
#   lr, Value: 0.005631965353179367
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 4
#
# epoch : 1 validation error : 0.4765625
# epoch : 2 validation error : 0.259765625
# epoch : 3 validation error : 0.16796875
# epoch : 4 validation error : 0.15234375
# epoch : 5 validation error : 0.12890625
# epoch : 6 validation error : 0.1171875
# epoch : 7 validation error : 0.107421875
# epoch : 8 validation error : 0.103515625
# Configuration:
#   lr, Value: 0.014584254639384796
#   num_conv_layers, Value: 2
#   num_filters_1, Value: 8
#   num_filters_2, Value: 3
#
# epoch : 1 validation error : 0.82421875
# epoch : 2 validation error : 0.375
# epoch : 3 validation error : 0.19140625
# epoch : 4 validation error : 0.181640625
# epoch : 5 validation error : 0.169921875
# epoch : 6 validation error : 0.14453125
# epoch : 7 validation error : 0.1953125
# epoch : 8 validation error : 0.134765625
# Configuration:
#   lr, Value: 0.0026702786576428077
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 6
#
# epoch : 1 validation error : 0.501953125
# epoch : 2 validation error : 0.30078125
# epoch : 3 validation error : 0.2421875
# epoch : 4 validation error : 0.201171875
# epoch : 5 validation error : 0.169921875
# epoch : 6 validation error : 0.146484375
# epoch : 7 validation error : 0.14453125
# epoch : 8 validation error : 0.13671875
# Configuration:
#   lr, Value: 0.017598973497905138
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 6
#
# epoch : 1 validation error : 0.150390625
# epoch : 2 validation error : 0.12890625
# epoch : 3 validation error : 0.107421875
# epoch : 4 validation error : 0.107421875
# epoch : 5 validation error : 0.1015625
# epoch : 6 validation error : 0.103515625
# epoch : 7 validation error : 0.1015625
# epoch : 8 validation error : 0.08984375
# Configuration:
#   lr, Value: 0.08327731421075717
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 8
#
# epoch : 1 validation error : 0.140625
# epoch : 2 validation error : 0.09375
# epoch : 3 validation error : 0.09765625
# epoch : 4 validation error : 0.083984375
# epoch : 5 validation error : 0.07421875
# epoch : 6 validation error : 0.08203125
# epoch : 7 validation error : 0.06640625
# epoch : 8 validation error : 0.06640625
# Configuration:
#   lr, Value: 2.6856059072094764e-06
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 2
#
# epoch : 1 validation error : 0.935546875
# epoch : 2 validation error : 0.935546875
# epoch : 3 validation error : 0.935546875
# epoch : 4 validation error : 0.935546875
# epoch : 5 validation error : 0.935546875
# epoch : 6 validation error : 0.935546875
# epoch : 7 validation error : 0.935546875
# epoch : 8 validation error : 0.935546875
# Configuration:
#   lr, Value: 0.003625733649970484
#   num_conv_layers, Value: 2
#   num_filters_1, Value: 6
#   num_filters_2, Value: 5
#
# epoch : 1 validation error : 0.875
# epoch : 2 validation error : 0.853515625
# epoch : 3 validation error : 0.845703125
# epoch : 4 validation error : 0.767578125
# epoch : 5 validation error : 0.640625
# epoch : 6 validation error : 0.4609375
# epoch : 7 validation error : 0.35546875
# epoch : 8 validation error : 0.296875
# Configuration:
#   lr, Value: 2.466555596994864e-06
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 6
#
# epoch : 1 validation error : 0.947265625
# epoch : 2 validation error : 0.947265625
# epoch : 3 validation error : 0.947265625
# epoch : 4 validation error : 0.947265625
# epoch : 5 validation error : 0.94921875
# epoch : 6 validation error : 0.94921875
# epoch : 7 validation error : 0.94921875
# epoch : 8 validation error : 0.94921875

# %% [markdown]
# ### Evaluate
#
# Now we should evaluate the previous runs. Evaluation in hyperparameter optimization can mean two different things: On the one hand, we might be only interested in the model with the best performance. On the other hand, we might want to find the best hyperparameter configuration to then train a model with these hyper-parameters (but with e.g. more epochs).
#
# **Task:** Print the model and final validation error of the best model in `results`.

# %%
# START TODO ################
def myfunc(item):
    return item[2][-1]

def plot_graph(results):
    fig,ax= plt.subplots(figsize=(20,20))
    ax.set_title('Validation Loss')
    ax.set_xlabel('Epoch')
    ax.set_ylabel('Validation Loss')
    for i in range(len(results)):
        ax.plot(results[i][2], label=results[i][1])
    ax.legend(loc='upper right')
    fig.canvas.draw()
    
    
    
results.sort(key=myfunc)

#print(results)

best = results[0]
print("best config " ,best)

# END TODO ################
# Out:
# best config  (Sequential(
#   (0): Conv2d(1, 8, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Flatten()
#   (4): Linear(in_features=1352, out_features=10, bias=True)
#   (5): LogSoftmax()
# ), Configuration:
#   lr, Value: 0.08327731421075717
#   num_conv_layers, Value: 1
#   num_filters_1, Value: 8
# , [0.140625, 0.09375, 0.09765625, 0.083984375, 0.07421875, 0.08203125, 0.06640625, 0.06640625])

# %% [markdown]
# Let's further investigate which hyperparameters work well and which don't.
#
# **Task:** Print a scatter plot of learning rate (x) and number of filters (sum over layers, y). Scale the size of the scatter points by the error in the last epoch (10 to 100).

# %%
# START TODO ################
errors = [res[2][-1] for res in results]
scale = [e for _, e in sorted(zip(np.argsort(errors), np.linspace(10, 100, len(errors))))]
for i in range(len(results)):
    if(results[i][1]['num_conv_layers']>1):
        sum_=results[i][1]['num_filters_1']+results[i][1]['num_filters_2']
    else:
        sum_=results[i][1]['num_filters_1']
    #print(results[i][2][-1]*100)
    plt.scatter(np.log(results[i][1]['lr']),sum_, s=results[i][2][-1]*100)
    plt.xlabel('learning  rate')
    plt.ylabel('total number of filters')
    #plt.xlim([1e-05,1e-01])
# END TODO ################

# %% [markdown]
# **Question:** What pattern do you see? Why might it occur?
#
# **Answer:** **TODO**

# %% [markdown]
# After looking at the final error, let's now have a look at the training error.
#
# **Task:** Plot error curves (error per epoch) for all your configurations in one figure.

# %%
# START TODO ################

plot_graph(results)

# END TODO ################

# %% [markdown]
# **Questions:** How could you detect configurations with a low error earlier/faster? Why could this be problematic?
#
# **Answers:** **TODO**

# %% [markdown]
# ### Your Feedback on Exercise 6.1

# %% [markdown]
# ## BOHB
#
# Here we will use the more advanced hyperparameter optimizer [BOHB](https://www.automl.org/blog_bohb/) (Bayesian Optimization with Hyperband).
# Based on [Hyperband](https://arxiv.org/pdf/1603.06560.pdf), BOHB evaluates configurations on your model with increasing budgets. In the context of Deep Learning, budget can be the number of epochs or the number of training samples. In lower budget evaluations, BOHB can look at more configurations. Full budget evaluations avoid missing configurations which are poor at the beginnning but good at the end (and vice versa).
# At the start of a run, BOHB samples configurations randomly. After some time, BOHB then uses a bayesian model (based on Parzen Tree Estimators), sampling only promising configs.
#
# This exercise part is based on the [HpBandSter Examples](https://automl.github.io/HpBandSter/build/html/auto_examples/index.html) and the [HpBandSter Documentation](https://automl.github.io/HpBandSter/). *HpBandSter* provides a fast implementation of *Randomsearch*, *Hyperband* and *BOHB*. The optimization can easily be distributed between multiple cores or even multiple computers.

# %%
import pickle
import logging

from hpbandster.core.worker import Worker
import hpbandster.core.nameserver as hpns
import hpbandster.core.result as hpres
from hpbandster.optimizers import BOHB

logging.getLogger('hpbandster').setLevel(logging.DEBUG)
# Out:
# C:\Users\MYPC\Anaconda3\lib\site-packages\Pyro4\util.py:839: UserWarning: msgpack serializer unavailable. requires msgpack 0.5.2+, found (0, 5, 1)
#   warnings.warn("msgpack serializer unavailable. requires msgpack 0.5.2+, found " + str(msgpack.version))
# C:\Users\MYPC\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ### Implement Worker
#
# The worker defines the hyperparameter problem which we try to optimize.
# *compute(...)* should - for a given configuration and budget - return a loss which the hyperparameter optimizer tries to minimize. In our case, we can use the number of epochs as budget and the validation error as loss.
# As best practice, we define the configuration space also in the worker.
#
# If you need help, you might get some inspiration from the [HpBandSter Pytorch Worker Example](https://automl.github.io/HpBandSter/build/html/auto_examples/example_5_pytorch_worker.html#sphx-glr-auto-examples-example-5-pytorch-worker-py).
#
# **Task:** Complete the methods below.

# %%
class PyTorchWorker(Worker):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.train_loader, self.validation_loader, self.test_loader =\
            load_mnist_minibatched(batch_size=32, n_train=4096, n_valid=512)

    @staticmethod
    def get_model(config: CS.Configuration) -> nn.Module:
        """ Define a configurable convolution model.
            
        See description of get_conv_model above for more details on the model.
        """
        # START TODO ################
        #raise NotImplementedError
        
        #(28-3+0)/1+1=26
        #(26-2)/2+1=13
        #(13-3+0)/1+1=11
        #(11-2)/3+1=4
        #(4-3+0)/1+1=2
        #(2-2)/2+1=1
        
        
        
        conv_kernel_size = 3
        pool_kernel_size = 2
        if(config['num_conv_layers']==1):
            num_filters_1 = config['num_filters_1']
            model = nn.Sequential(nn.Conv2d(in_channels=1,
                                     out_channels=num_filters_1,
                                     kernel_size=conv_kernel_size,
                                     stride=1,
                                     padding=0),
                           nn.ReLU(),
                           nn.MaxPool2d(kernel_size=pool_kernel_size, stride=2, padding=0),
                           Flatten(),
                           nn.Linear(num_filters_1 * 13 * 13, 10),
                           nn.LogSoftmax())
        
        if(config['num_conv_layers']==2):
            num_filters_1 = config['num_filters_1']
            num_filters_2 = config['num_filters_2']
            model = nn.Sequential(nn.Conv2d(in_channels=1,
                                     out_channels=num_filters_1,
                                     kernel_size=conv_kernel_size,
                                     stride=1,
                                     padding=0),
                           nn.ReLU(),
                           nn.MaxPool2d(kernel_size=pool_kernel_size, stride=2, padding=0),
                                          
                           nn.Conv2d(in_channels=num_filters_1,
                                     out_channels=num_filters_2,
                                     kernel_size=conv_kernel_size,
                                     stride=1,
                                     padding=0),
                           nn.ReLU(),
                           nn.MaxPool2d(kernel_size=pool_kernel_size, stride=3, padding=0),               
                                          
                           
                           Flatten(),
                           nn.Linear(num_filters_2 * 4 * 4, 10),
                           nn.LogSoftmax())
                
        if(config['num_conv_layers']==3):
            num_filters_1 = config['num_filters_1']
            num_filters_2 = config['num_filters_2']
            num_filters_3 = config['num_filters_3']
            model = nn.Sequential(nn.Conv2d(in_channels=1,
                                     out_channels=num_filters_1,
                                     kernel_size=conv_kernel_size,
                                     stride=1,
                                     padding=0),
                           nn.ReLU(),
                           nn.MaxPool2d(kernel_size=pool_kernel_size, stride=2, padding=0),
                                          
                           nn.Conv2d(in_channels=num_filters_1,
                                     out_channels=num_filters_2,
                                     kernel_size=conv_kernel_size,
                                     stride=1,
                                     padding=0),
                           nn.ReLU(),
                           nn.MaxPool2d(kernel_size=pool_kernel_size, stride=3, padding=0),               
                           
                                                                                    
                           nn.Conv2d(in_channels=num_filters_2,
                                     out_channels=num_filters_3,
                                     kernel_size=conv_kernel_size,
                                     stride=1,
                                     padding=0),
                           nn.ReLU(),
                           nn.MaxPool2d(kernel_size=pool_kernel_size, stride=2, padding=0), 
                           
                           Flatten(),
                           nn.Linear(num_filters_3 * 1 * 1, 10),
                           nn.LogSoftmax())
            
  
        # END TODO ################
        return model
    @staticmethod
    def get_configspace() -> CS.Configuration:
        """ Define a conditional hyperparameter search-space.
    
        hyperparameters:
          num_filters_1   from    4 to   32 (int)
          num_filters_2   from    4 to   32 (int)
          num_filters_3   from    4 to   32 (int)
          num_conv_layers from    1 to    3 (int)
          lr              from 1e-6 to 1e-1 (float, log)
          sgd_momentum    from 0.00 to 0.99 (float)
          optimizer            Adam or  SGD (categoric)
          
        conditions: 
          include num_filters_2 only if num_conv_layers > 1
          include num_filters_3 only if num_conv_layers > 2
          include sgd_momentum  only if       optimizer = SGD
        """
        # START TODO ################
        #raise NotImplementedError
        
        cs = CS.ConfigurationSpace()
        lr = CSH.UniformFloatHyperparameter('lr', lower=1e-06, upper=1e-1, default_value='0.1', log=True)
        num_filters_1 = CSH.UniformIntegerHyperparameter('num_filters_1',lower=4,upper=32,log=False)
        num_filters_2 = CSH.UniformIntegerHyperparameter('num_filters_2',lower=4,upper=32,log=False)
        num_filters_3 = CSH.UniformIntegerHyperparameter('num_filters_3',lower=4,upper=32,log=False)
        num_conv_layers = CSH.UniformIntegerHyperparameter('num_conv_layers',lower=1,upper=3,log=False)
        optimizer = CSH.CategoricalHyperparameter('optimizer', ['Adam', 'SGD'])
        sgd_momentum = CSH.UniformFloatHyperparameter('sgd_momentum', lower=0.00, upper=0.99, log=False)
        cs.add_hyperparameters([lr])
        cs.add_hyperparameters([num_filters_1])
        cs.add_hyperparameters([num_filters_2])
        cs.add_hyperparameters([num_filters_3])
        cs.add_hyperparameters([num_conv_layers])
        cs.add_hyperparameters([optimizer])
        cs.add_hyperparameters([sgd_momentum])
        cs.add_condition(CS.GreaterThanCondition(num_filters_2,num_conv_layers,1))
        cs.add_condition(CS.GreaterThanCondition(num_filters_3,num_conv_layers,2))
        cs.add_condition(CS.EqualsCondition(sgd_momentum,optimizer,'SGD'))
        # END TODO ################        
        return cs
        
  


    def compute(self, config: CS.Configuration, budget: float, working_directory: str,
                *args, **kwargs) -> float:
        """Evaluate a function with the given config and budget and return a loss.
        
        Bohb tries to minimize the returned loss.
        
        In our case the function is the training and validation of a model,
        the budget is the number of epochs and the loss is the validation error.
        """
        model = self.get_model(config)
        
        # START TODO ################
        
        optim = config['optimizer']
        if(optim=='SGD'):
            optimizer = torch.optim.SGD(model.parameters(), lr = config['lr'],momentum=config['sgd_momentum'])
        else:
            optimizer= torch.optim.Adam(model.parameters(), lr = config['lr'])
        
        
        for epoch in range (1,int(budget)):
            model.train()
            for idx,data in enumerate(train_loader):
                inputs, labels = data
                optimizer.zero_grad()
                outputs = model(inputs)
                loss= F.nll_loss(outputs,labels)
                loss.backward()
                optimizer.step()

        # END TODO ################
        model.eval()
        train_accuracy = evaluate_accuracy(model, self.train_loader)
        validation_accuracy = evaluate_accuracy(model, self.validation_loader)
        test_accuracy = evaluate_accuracy(model, self.test_loader)
        
        return ({
                'loss': 1 - validation_accuracy,  # remember: HpBandSter minimizes the loss!
                'info': {'test_accuracy': test_accuracy,
                         'train_accuracy': train_accuracy,
                         'valid_accuracy': validation_accuracy,
                         'model': str(model)}
                })

# %% [markdown]
# It's best practice to do a quick sanity check of our worker with a low budget:

# %%
working_dir = os.curdir
# minimum budget that BOHB uses
min_budget = 1
# largest budget BOHB will use
max_budget = 9

# %%
worker = PyTorchWorker(run_id='0')
cs = worker.get_configspace()

config = cs.sample_configuration().get_dictionary()
print(config)

res = worker.compute(config=config, budget=min_budget, working_directory=working_dir)
print(res)
# Out:
# {'lr': 2.029317788149091e-05, 'num_conv_layers': 3, 'num_filters_1': 6, 'optimizer': 'Adam', 'num_filters_2': 32, 'num_filters_3': 7}
# C:\Users\MYPC\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# {'loss': 0.890625, 'info': {'test_accuracy': 0.101, 'train_accuracy': 0.097412109375, 'valid_accuracy': 0.109375, 'model': 'Sequential(\n  (0): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(6, 32, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Conv2d(32, 7, kernel_size=(3, 3), stride=(1, 1))\n  (7): ReLU()\n  (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (9): Flatten()\n  (10): Linear(in_features=7, out_features=10, bias=True)\n  (11): LogSoftmax()\n)'}}

# %% [markdown]
# ### Run BOHB
#
# We now run the hyperparameter search with BOHB and the worker which we defined above and save the result to disk.
# Try to understand what happens. *HpBandSter* allows to start additional workers on the same or remote devices to parallelize the executions, that's why we need to setup some network stuff (nameserver, nic, host, port, …). If you're interested, you can check this out in the [HpBandSter Examples](https://automl.github.io/HpBandSter/build/html/auto_examples/index.html), but it is beyond the scope of this exercise.
#
# **Note:** The code below will try 60 different configurations. Some of them are executed at multiple budgets, which results in about 80 model training. Therefore it might take a while (15-45 minutes on a laptop). If you are interested in how BOHB works, checkout [BOHB (Falkner et al. 2018)](http://proceedings.mlr.press/v80/falkner18a.html).
#
# **Note 2:** You can see the progress in the debug output below. The configuration identifier (called `config_id` in the docs) is a three-tuple `(current iteration, resampling in case of error, sample)`.

# %%
result_file = os.path.join(working_dir, 'bohb_result.pkl')
nic_name = 'lo'
port = 0
run_id = 'bohb_run_1'
n_bohb_iterations = 12

# %%
try:
    # Start a nameserver
    #host = hpns.nic_name_to_host(nic_name)
    ns = hpns.NameServer(run_id=run_id, host='127.0.0.1', port=None,
                         working_directory=working_dir)
    ns_host, ns_port = ns.start()

    # Start local worker
    w = PyTorchWorker(run_id=run_id, host='127.0.0.1', nameserver=ns_host,
                      nameserver_port=ns_port, timeout=120)
    w.run(background=True)

    # Run an optimizer
    bohb = BOHB(configspace=worker.get_configspace(),
                run_id=run_id,
                host='127.0.0.1',
                nameserver=ns_host,
                nameserver_port=ns_port,
                min_budget=min_budget, max_budget=max_budget)
    
    result = bohb.run(n_iterations=n_bohb_iterations)
    print("Write result to file {}".format(result_file))
    with open(result_file, 'wb') as f:
        pickle.dump(result, f)
finally:
    bohb.shutdown(shutdown_workers=True)
    ns.shutdown()
# Out:
# 02:19:22 WORKER: Connected to nameserver <Pyro4.core.Proxy at 0x19bbdb9a908; connected IPv4; for PYRO:Pyro.NameServer@127.0.0.1:9090>
# 02:19:22 wait_for_workers trying to get the condition
# 02:19:22 DISPATCHER: started the 'discover_worker' thread
# 02:19:22 WORKER: No dispatcher found. Waiting for one to initiate contact.
# 02:19:22 DISPATCHER: started the 'job_runner' thread
# 02:19:22 WORKER: start listening for jobs
# 02:19:22 DISPATCHER: Pyro daemon running on 127.0.0.1:52321
# 02:19:22 DISPATCHER: Starting worker discovery
# 02:19:22 DISPATCHER: Found 1 potential workers, 0 currently in the pool.
# 02:19:22 DISPATCHER: discovered new worker, hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:22 HBMASTER: number of workers changed to 1
# 02:19:22 adjust_queue_size: lock accquired
# 02:19:22 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:22 Enough workers to start this run!
# 02:19:22 HBMASTER: adjusted queue size to (0, 1)
# 02:19:22 HBMASTER: starting run at 1543713562.9872756
# 02:19:22 DISPATCHER: Finished worker discovery
# 02:19:22 start sampling a new configuration.
# 02:19:22 DISPATCHER: Trying to submit another job.
# 02:19:22 done sampling a new configuration.
# 02:19:22 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:22 HBMASTER: schedule new run for iteration 0
# 02:19:23 HBMASTER: trying submitting job (0, 0, 0) to dispatcher
# 02:19:23 HBMASTER: submitting job (0, 0, 0) to dispatcher
# 02:19:23 DISPATCHER: trying to submit job (0, 0, 0)
# 02:19:23 DISPATCHER: trying to notify the job_runner thread.
# 02:19:23 HBMASTER: job (0, 0, 0) submitted to dispatcher
# 02:19:23 DISPATCHER: Trying to submit another job.
# 02:19:23 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:23 DISPATCHER: starting job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:23 DISPATCHER: job (0, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:23 WORKER: start processing job (0, 0, 0)
# 02:19:23 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:23 WORKER: args: ()
# 02:19:23 WORKER: kwargs: {'config': {'lr': 3.3181549322643076e-06, 'num_conv_layers': 3, 'num_filters_1': 11, 'optimizer': 'Adam', 'num_filters_2': 29, 'num_filters_3': 14}, 'budget': 1.0, 'working_directory': '.'}
# C:\Users\MYPC\Anaconda3\lib\site-packages\torch\nn\modules\container.py:91: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# 02:19:25 WORKER: done with job (0, 0, 0), trying to register it.
# 02:19:25 WORKER: registered result for job (0, 0, 0) with dispatcher
# 02:19:25 DISPATCHER: job (0, 0, 0) finished
# 02:19:25 DISPATCHER: register_result: lock acquired
# 02:19:25 DISPATCHER: job (0, 0, 0) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:19:25 job_id: (0, 0, 0)
# kwargs: {'config': {'lr': 3.3181549322643076e-06, 'num_conv_layers': 3, 'num_filters_1': 11, 'optimizer': 'Adam', 'num_filters_2': 29, 'num_filters_3': 14}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.91796875, 'info': {'test_accuracy': 0.0892, 'train_accuracy': 0.087890625, 'valid_accuracy': 0.08203125, 'model': 'Sequential(\n  (0): Conv2d(1, 11, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(11, 29, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Conv2d(29, 14, kernel_size=(3, 3), stride=(1, 1))\n  (7): ReLU()\n  (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (9): Flatten()\n  (10): Linear(in_features=14, out_features=10, bias=True)\n  (11): LogSoftmax()\n)'}}
# exception: None
#
# 02:19:25 job_callback for (0, 0, 0) started
# 02:19:25 DISPATCHER: Trying to submit another job.
# 02:19:25 job_callback for (0, 0, 0) got condition
# 02:19:25 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:25 Only 1 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 02:19:25 HBMASTER: Trying to run another job!
# 02:19:25 job_callback for (0, 0, 0) finished
# 02:19:25 start sampling a new configuration.
# 02:19:25 done sampling a new configuration.
# 02:19:25 HBMASTER: schedule new run for iteration 0
# 02:19:25 HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# 02:19:25 HBMASTER: submitting job (0, 0, 1) to dispatcher
# 02:19:25 DISPATCHER: trying to submit job (0, 0, 1)
# 02:19:25 DISPATCHER: trying to notify the job_runner thread.
# 02:19:25 HBMASTER: job (0, 0, 1) submitted to dispatcher
# 02:19:25 DISPATCHER: Trying to submit another job.
# 02:19:25 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:25 DISPATCHER: starting job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:25 DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:25 WORKER: start processing job (0, 0, 1)
# 02:19:25 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:25 WORKER: args: ()
# 02:19:25 WORKER: kwargs: {'config': {'lr': 2.7832714415839465e-05, 'num_conv_layers': 2, 'num_filters_1': 7, 'optimizer': 'Adam', 'num_filters_2': 11}, 'budget': 1.0, 'working_directory': '.'}
# 02:19:28 WORKER: done with job (0, 0, 1), trying to register it.
# 02:19:28 WORKER: registered result for job (0, 0, 1) with dispatcher
# 02:19:28 DISPATCHER: job (0, 0, 1) finished
# 02:19:28 DISPATCHER: register_result: lock acquired
# 02:19:28 DISPATCHER: job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:19:28 job_id: (0, 0, 1)
# kwargs: {'config': {'lr': 2.7832714415839465e-05, 'num_conv_layers': 2, 'num_filters_1': 7, 'optimizer': 'Adam', 'num_filters_2': 11}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.865234375, 'info': {'test_accuracy': 0.1302, 'train_accuracy': 0.12548828125, 'valid_accuracy': 0.134765625, 'model': 'Sequential(\n  (0): Conv2d(1, 7, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(7, 11, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Flatten()\n  (7): Linear(in_features=176, out_features=10, bias=True)\n  (8): LogSoftmax()\n)'}}
# exception: None
#
# 02:19:28 job_callback for (0, 0, 1) started
# 02:19:28 DISPATCHER: Trying to submit another job.
# 02:19:28 job_callback for (0, 0, 1) got condition
# 02:19:28 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:28 Only 2 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 02:19:28 HBMASTER: Trying to run another job!
# 02:19:28 job_callback for (0, 0, 1) finished
# 02:19:28 start sampling a new configuration.
# 02:19:28 done sampling a new configuration.
# 02:19:28 HBMASTER: schedule new run for iteration 0
# 02:19:28 HBMASTER: trying submitting job (0, 0, 2) to dispatcher
# 02:19:28 HBMASTER: submitting job (0, 0, 2) to dispatcher
# 02:19:28 DISPATCHER: trying to submit job (0, 0, 2)
# 02:19:28 DISPATCHER: trying to notify the job_runner thread.
# 02:19:28 HBMASTER: job (0, 0, 2) submitted to dispatcher
# 02:19:28 DISPATCHER: Trying to submit another job.
# 02:19:28 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:28 DISPATCHER: starting job (0, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:28 DISPATCHER: job (0, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:28 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:28 WORKER: start processing job (0, 0, 2)
# 02:19:28 WORKER: args: ()
# 02:19:28 WORKER: kwargs: {'config': {'lr': 0.0011696102196096336, 'num_conv_layers': 1, 'num_filters_1': 11, 'optimizer': 'SGD', 'sgd_momentum': 0.13845430546126702}, 'budget': 1.0, 'working_directory': '.'}
# 02:19:30 WORKER: done with job (0, 0, 2), trying to register it.
# 02:19:30 WORKER: registered result for job (0, 0, 2) with dispatcher
# 02:19:30 DISPATCHER: job (0, 0, 2) finished
# 02:19:30 DISPATCHER: register_result: lock acquired
# 02:19:30 DISPATCHER: job (0, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:19:30 job_id: (0, 0, 2)
# kwargs: {'config': {'lr': 0.0011696102196096336, 'num_conv_layers': 1, 'num_filters_1': 11, 'optimizer': 'SGD', 'sgd_momentum': 0.13845430546126702}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.931640625, 'info': {'test_accuracy': 0.0826, 'train_accuracy': 0.07568359375, 'valid_accuracy': 0.068359375, 'model': 'Sequential(\n  (0): Conv2d(1, 11, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Flatten()\n  (4): Linear(in_features=1859, out_features=10, bias=True)\n  (5): LogSoftmax()\n)'}}
# exception: None
#
# 02:19:30 job_callback for (0, 0, 2) started
# 02:19:30 DISPATCHER: Trying to submit another job.
# 02:19:30 job_callback for (0, 0, 2) got condition
# 02:19:30 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:30 Only 3 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 02:19:30 HBMASTER: Trying to run another job!
# 02:19:30 job_callback for (0, 0, 2) finished
# 02:19:30 start sampling a new configuration.
# 02:19:30 done sampling a new configuration.
# 02:19:30 HBMASTER: schedule new run for iteration 0
# 02:19:30 HBMASTER: trying submitting job (0, 0, 3) to dispatcher
# 02:19:30 HBMASTER: submitting job (0, 0, 3) to dispatcher
# 02:19:30 DISPATCHER: trying to submit job (0, 0, 3)
# 02:19:30 DISPATCHER: trying to notify the job_runner thread.
# 02:19:30 HBMASTER: job (0, 0, 3) submitted to dispatcher
# 02:19:30 DISPATCHER: Trying to submit another job.
# 02:19:30 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:30 DISPATCHER: starting job (0, 0, 3) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:30 DISPATCHER: job (0, 0, 3) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:30 WORKER: start processing job (0, 0, 3)
# 02:19:30 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:30 WORKER: args: ()
# 02:19:30 WORKER: kwargs: {'config': {'lr': 3.9774081246655e-06, 'num_conv_layers': 1, 'num_filters_1': 18, 'optimizer': 'SGD', 'sgd_momentum': 0.5181461538320108}, 'budget': 1.0, 'working_directory': '.'}
# 02:19:33 WORKER: done with job (0, 0, 3), trying to register it.
# 02:19:33 WORKER: registered result for job (0, 0, 3) with dispatcher
# 02:19:33 DISPATCHER: job (0, 0, 3) finished
# 02:19:33 DISPATCHER: register_result: lock acquired
# 02:19:33 DISPATCHER: job (0, 0, 3) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:19:33 job_id: (0, 0, 3)
# kwargs: {'config': {'lr': 3.9774081246655e-06, 'num_conv_layers': 1, 'num_filters_1': 18, 'optimizer': 'SGD', 'sgd_momentum': 0.5181461538320108}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.923828125, 'info': {'test_accuracy': 0.0663, 'train_accuracy': 0.059814453125, 'valid_accuracy': 0.076171875, 'model': 'Sequential(\n  (0): Conv2d(1, 18, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Flatten()\n  (4): Linear(in_features=3042, out_features=10, bias=True)\n  (5): LogSoftmax()\n)'}}
# exception: None
#
# 02:19:33 job_callback for (0, 0, 3) started
# 02:19:33 DISPATCHER: Trying to submit another job.
# 02:19:33 job_callback for (0, 0, 3) got condition
# 02:19:33 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:33 Only 4 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 02:19:33 HBMASTER: Trying to run another job!
# 02:19:33 job_callback for (0, 0, 3) finished
# 02:19:33 start sampling a new configuration.
# 02:19:33 done sampling a new configuration.
# 02:19:33 HBMASTER: schedule new run for iteration 0
# 02:19:33 HBMASTER: trying submitting job (0, 0, 4) to dispatcher
# 02:19:33 HBMASTER: submitting job (0, 0, 4) to dispatcher
# 02:19:33 DISPATCHER: trying to submit job (0, 0, 4)
# 02:19:33 DISPATCHER: trying to notify the job_runner thread.
# 02:19:33 HBMASTER: job (0, 0, 4) submitted to dispatcher
# 02:19:33 DISPATCHER: Trying to submit another job.
# 02:19:33 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:33 DISPATCHER: starting job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:33 DISPATCHER: job (0, 0, 4) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:33 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:33 WORKER: start processing job (0, 0, 4)
# 02:19:33 WORKER: args: ()
# 02:19:33 WORKER: kwargs: {'config': {'lr': 0.00042412532047657, 'num_conv_layers': 1, 'num_filters_1': 27, 'optimizer': 'Adam'}, 'budget': 1.0, 'working_directory': '.'}
# 02:19:37 WORKER: done with job (0, 0, 4), trying to register it.
# 02:19:37 WORKER: registered result for job (0, 0, 4) with dispatcher
# 02:19:37 DISPATCHER: job (0, 0, 4) finished
# 02:19:37 DISPATCHER: register_result: lock acquired
# 02:19:37 DISPATCHER: job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:19:37 job_id: (0, 0, 4)
# kwargs: {'config': {'lr': 0.00042412532047657, 'num_conv_layers': 1, 'num_filters_1': 27, 'optimizer': 'Adam'}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.85546875, 'info': {'test_accuracy': 0.1261, 'train_accuracy': 0.137939453125, 'valid_accuracy': 0.14453125, 'model': 'Sequential(\n  (0): Conv2d(1, 27, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Flatten()\n  (4): Linear(in_features=4563, out_features=10, bias=True)\n  (5): LogSoftmax()\n)'}}
# exception: None
#
# 02:19:37 job_callback for (0, 0, 4) started
# 02:19:37 DISPATCHER: Trying to submit another job.
# 02:19:37 job_callback for (0, 0, 4) got condition
# 02:19:37 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:37 Only 5 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 02:19:37 HBMASTER: Trying to run another job!
# 02:19:37 job_callback for (0, 0, 4) finished
# 02:19:37 start sampling a new configuration.
# 02:19:37 done sampling a new configuration.
# 02:19:37 HBMASTER: schedule new run for iteration 0
# 02:19:37 HBMASTER: trying submitting job (0, 0, 5) to dispatcher
# 02:19:37 HBMASTER: submitting job (0, 0, 5) to dispatcher
# 02:19:37 DISPATCHER: trying to submit job (0, 0, 5)
# 02:19:37 DISPATCHER: trying to notify the job_runner thread.
# 02:19:37 HBMASTER: job (0, 0, 5) submitted to dispatcher
# 02:19:37 DISPATCHER: Trying to submit another job.
# 02:19:37 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:37 DISPATCHER: starting job (0, 0, 5) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:37 DISPATCHER: job (0, 0, 5) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:37 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:37 WORKER: start processing job (0, 0, 5)
# 02:19:37 WORKER: args: ()
# 02:19:37 WORKER: kwargs: {'config': {'lr': 1.4189525294639134e-05, 'num_conv_layers': 2, 'num_filters_1': 26, 'optimizer': 'SGD', 'num_filters_2': 29, 'sgd_momentum': 0.13422015079673785}, 'budget': 1.0, 'working_directory': '.'}
# 02:19:43 WORKER: done with job (0, 0, 5), trying to register it.
# 02:19:43 WORKER: registered result for job (0, 0, 5) with dispatcher
# 02:19:43 DISPATCHER: job (0, 0, 5) finished
# 02:19:43 DISPATCHER: register_result: lock acquired
# 02:19:43 DISPATCHER: job (0, 0, 5) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:19:43 job_id: (0, 0, 5)
# kwargs: {'config': {'lr': 1.4189525294639134e-05, 'num_conv_layers': 2, 'num_filters_1': 26, 'optimizer': 'SGD', 'num_filters_2': 29, 'sgd_momentum': 0.13422015079673785}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.908203125, 'info': {'test_accuracy': 0.0971, 'train_accuracy': 0.104736328125, 'valid_accuracy': 0.091796875, 'model': 'Sequential(\n  (0): Conv2d(1, 26, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(26, 29, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Flatten()\n  (7): Linear(in_features=464, out_features=10, bias=True)\n  (8): LogSoftmax()\n)'}}
# exception: None
# 02:19:43 job_callback for (0, 0, 5) started
# 02:19:43 DISPATCHER: Trying to submit another job.
# 02:19:43 job_callback for (0, 0, 5) got condition
# 02:19:43 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:43 Only 6 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 02:19:43 HBMASTER: Trying to run another job!
# 02:19:43 job_callback for (0, 0, 5) finished
# 02:19:43 start sampling a new configuration.
# 02:19:43 done sampling a new configuration.
# 02:19:43 HBMASTER: schedule new run for iteration 0
# 02:19:43 HBMASTER: trying submitting job (0, 0, 6) to dispatcher
# 02:19:43 HBMASTER: submitting job (0, 0, 6) to dispatcher
# 02:19:43 DISPATCHER: trying to submit job (0, 0, 6)
# 02:19:43 DISPATCHER: trying to notify the job_runner thread.
# 02:19:43 HBMASTER: job (0, 0, 6) submitted to dispatcher
# 02:19:43 DISPATCHER: Trying to submit another job.
# 02:19:43 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:43 DISPATCHER: starting job (0, 0, 6) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:43 DISPATCHER: job (0, 0, 6) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:43 WORKER: start processing job (0, 0, 6)
# 02:19:43 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:43 WORKER: args: ()
# 02:19:43 WORKER: kwargs: {'config': {'lr': 0.0017874694916816638, 'num_conv_layers': 1, 'num_filters_1': 25, 'optimizer': 'SGD', 'sgd_momentum': 0.029856293783612178}, 'budget': 1.0, 'working_directory': '.'}
# 02:19:47 WORKER: done with job (0, 0, 6), trying to register it.
# 02:19:47 WORKER: registered result for job (0, 0, 6) with dispatcher
# 02:19:47 DISPATCHER: job (0, 0, 6) finished
# 02:19:47 DISPATCHER: register_result: lock acquired
# 02:19:47 DISPATCHER: job (0, 0, 6) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:19:47 job_id: (0, 0, 6)
# kwargs: {'config': {'lr': 0.0017874694916816638, 'num_conv_layers': 1, 'num_filters_1': 25, 'optimizer': 'SGD', 'sgd_momentum': 0.029856293783612178}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.892578125, 'info': {'test_accuracy': 0.1297, 'train_accuracy': 0.128662109375, 'valid_accuracy': 0.107421875, 'model': 'Sequential(\n  (0): Conv2d(1, 25, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Flatten()\n  (4): Linear(in_features=4225, out_features=10, bias=True)\n  (5): LogSoftmax()\n)'}}
# exception: None
#
# 02:19:47 job_callback for (0, 0, 6) started
# 02:19:47 DISPATCHER: Trying to submit another job.
# 02:19:47 job_callback for (0, 0, 6) got condition
# 02:19:47 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:47 Only 7 run(s) for budget 1.000000 available, need more than 9 -> can't build model!
# 02:19:47 HBMASTER: Trying to run another job!
# 02:19:47 job_callback for (0, 0, 6) finished
# 02:19:47 start sampling a new configuration.
# 02:19:47 done sampling a new configuration.
# 02:19:47 HBMASTER: schedule new run for iteration 0
# 02:19:47 HBMASTER: trying submitting job (0, 0, 7) to dispatcher
# 02:19:47 HBMASTER: submitting job (0, 0, 7) to dispatcher
# 02:19:47 DISPATCHER: trying to submit job (0, 0, 7)
# 02:19:47 DISPATCHER: trying to notify the job_runner thread.
# 02:19:47 HBMASTER: job (0, 0, 7) submitted to dispatcher
# 02:19:47 DISPATCHER: Trying to submit another job.
# 02:19:47 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:47 DISPATCHER: starting job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:47 DISPATCHER: job (0, 0, 7) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:47 WORKER: start processing job (0, 0, 7)
# 02:19:47 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:47 WORKER: args: ()
# 02:19:47 WORKER: kwargs: {'config': {'lr': 4.530869389500599e-05, 'num_conv_layers': 3, 'num_filters_1': 19, 'optimizer': 'Adam', 'num_filters_2': 28, 'num_filters_3': 9}, 'budget': 1.0, 'working_directory': '.'}
# 02:19:52 WORKER: done with job (0, 0, 7), trying to register it.
# 02:19:52 WORKER: registered result for job (0, 0, 7) with dispatcher
# 02:19:52 DISPATCHER: job (0, 0, 7) finished
# 02:19:52 DISPATCHER: register_result: lock acquired
# 02:19:52 DISPATCHER: job (0, 0, 7) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:19:52 job_id: (0, 0, 7)
# kwargs: {'config': {'lr': 4.530869389500599e-05, 'num_conv_layers': 3, 'num_filters_1': 19, 'optimizer': 'Adam', 'num_filters_2': 28, 'num_filters_3': 9}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.912109375, 'info': {'test_accuracy': 0.1009, 'train_accuracy': 0.100341796875, 'valid_accuracy': 0.087890625, 'model': 'Sequential(\n  (0): Conv2d(1, 19, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(19, 28, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Conv2d(28, 9, kernel_size=(3, 3), stride=(1, 1))\n  (7): ReLU()\n  (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (9): Flatten()\n  (10): Linear(in_features=9, out_features=10, bias=True)\n  (11): LogSoftmax()\n)'}}
# exception: None
#
# 02:19:52 job_callback for (0, 0, 7) started
# 02:19:52 DISPATCHER: Trying to submit another job.
# 02:19:52 job_callback for (0, 0, 7) got condition
# 02:19:52 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:52 HBMASTER: Trying to run another job!
# 02:19:52 job_callback for (0, 0, 7) finished
# 02:19:52 start sampling a new configuration.
# 02:19:52 done sampling a new configuration.
# 02:19:52 HBMASTER: schedule new run for iteration 0
# 02:19:52 HBMASTER: trying submitting job (0, 0, 8) to dispatcher
# 02:19:52 HBMASTER: submitting job (0, 0, 8) to dispatcher
# 02:19:52 DISPATCHER: trying to submit job (0, 0, 8)
# 02:19:52 DISPATCHER: trying to notify the job_runner thread.
# 02:19:52 HBMASTER: job (0, 0, 8) submitted to dispatcher
# 02:19:52 DISPATCHER: Trying to submit another job.
# 02:19:52 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:52 DISPATCHER: starting job (0, 0, 8) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:52 DISPATCHER: job (0, 0, 8) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:52 WORKER: start processing job (0, 0, 8)
# 02:19:52 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:52 WORKER: args: ()
# 02:19:52 WORKER: kwargs: {'config': {'lr': 0.010293268598884483, 'num_conv_layers': 2, 'num_filters_1': 13, 'optimizer': 'SGD', 'num_filters_2': 24, 'sgd_momentum': 0.2028065326684348}, 'budget': 1.0, 'working_directory': '.'}
# 02:19:55 WORKER: done with job (0, 0, 8), trying to register it.
# 02:19:55 WORKER: registered result for job (0, 0, 8) with dispatcher
# 02:19:55 DISPATCHER: job (0, 0, 8) finished
# 02:19:55 DISPATCHER: register_result: lock acquired
# 02:19:55 DISPATCHER: job (0, 0, 8) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:19:55 job_id: (0, 0, 8)
# kwargs: {'config': {'lr': 0.010293268598884483, 'num_conv_layers': 2, 'num_filters_1': 13, 'optimizer': 'SGD', 'num_filters_2': 24, 'sgd_momentum': 0.2028065326684348}, 'budget': 1.0, 'working_directory': '.'}
# result: {'loss': 0.935546875, 'info': {'test_accuracy': 0.0964, 'train_accuracy': 0.09375, 'valid_accuracy': 0.064453125, 'model': 'Sequential(\n  (0): Conv2d(1, 13, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(13, 24, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Flatten()\n  (7): Linear(in_features=384, out_features=10, bias=True)\n  (8): LogSoftmax()\n)'}}
# exception: None
#
# 02:19:55 job_callback for (0, 0, 8) started
# 02:19:55 DISPATCHER: Trying to submit another job.
# 02:19:55 job_callback for (0, 0, 8) got condition
# 02:19:55 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:19:55 HBMASTER: Trying to run another job!
# 02:19:55 job_callback for (0, 0, 8) finished
# 02:19:55 ITERATION: Advancing config (0, 0, 1) to next budget 3.000000
# 02:19:55 ITERATION: Advancing config (0, 0, 4) to next budget 3.000000
# 02:19:55 ITERATION: Advancing config (0, 0, 6) to next budget 3.000000
# 02:19:55 HBMASTER: schedule new run for iteration 0
# 02:19:55 HBMASTER: trying submitting job (0, 0, 1) to dispatcher
# 02:19:55 HBMASTER: submitting job (0, 0, 1) to dispatcher
# 02:19:55 DISPATCHER: trying to submit job (0, 0, 1)
# 02:19:55 DISPATCHER: trying to notify the job_runner thread.
# 02:19:55 HBMASTER: job (0, 0, 1) submitted to dispatcher
# 02:19:55 DISPATCHER: Trying to submit another job.
# 02:19:55 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:19:55 DISPATCHER: starting job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:55 DISPATCHER: job (0, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:19:55 WORKER: start processing job (0, 0, 1)
# 02:19:55 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:19:55 WORKER: args: ()
# 02:19:55 WORKER: kwargs: {'config': {'lr': 2.7832714415839465e-05, 'num_conv_layers': 2, 'num_filters_1': 7, 'optimizer': 'Adam', 'num_filters_2': 11}, 'budget': 3.0, 'working_directory': '.'}
# 02:20:01 WORKER: done with job (0, 0, 1), trying to register it.
# 02:20:01 WORKER: registered result for job (0, 0, 1) with dispatcher
# 02:20:01 DISPATCHER: job (0, 0, 1) finished
# 02:20:01 DISPATCHER: register_result: lock acquired
# 02:20:01 DISPATCHER: job (0, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:20:01 job_id: (0, 0, 1)
# kwargs: {'config': {'lr': 2.7832714415839465e-05, 'num_conv_layers': 2, 'num_filters_1': 7, 'optimizer': 'Adam', 'num_filters_2': 11}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.916015625, 'info': {'test_accuracy': 0.1011, 'train_accuracy': 0.09375, 'valid_accuracy': 0.083984375, 'model': 'Sequential(\n  (0): Conv2d(1, 7, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(7, 11, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Flatten()\n  (7): Linear(in_features=176, out_features=10, bias=True)\n  (8): LogSoftmax()\n)'}}
# exception: None
#
# 02:20:01 job_callback for (0, 0, 1) started
# 02:20:01 DISPATCHER: Trying to submit another job.
# 02:20:01 job_callback for (0, 0, 1) got condition
# 02:20:01 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:20:01 Only 1 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 02:20:01 HBMASTER: Trying to run another job!
# 02:20:01 job_callback for (0, 0, 1) finished
# 02:20:01 HBMASTER: schedule new run for iteration 0
# 02:20:01 HBMASTER: trying submitting job (0, 0, 4) to dispatcher
# 02:20:01 HBMASTER: submitting job (0, 0, 4) to dispatcher
# 02:20:01 DISPATCHER: trying to submit job (0, 0, 4)
# 02:20:01 DISPATCHER: trying to notify the job_runner thread.
# 02:20:01 HBMASTER: job (0, 0, 4) submitted to dispatcher
# 02:20:01 DISPATCHER: Trying to submit another job.
# 02:20:01 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:20:01 DISPATCHER: starting job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:01 DISPATCHER: job (0, 0, 4) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:01 WORKER: start processing job (0, 0, 4)
# 02:20:01 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:20:01 WORKER: args: ()
# 02:20:01 WORKER: kwargs: {'config': {'lr': 0.00042412532047657, 'num_conv_layers': 1, 'num_filters_1': 27, 'optimizer': 'Adam'}, 'budget': 3.0, 'working_directory': '.'}
# 02:20:10 WORKER: done with job (0, 0, 4), trying to register it.
# 02:20:10 WORKER: registered result for job (0, 0, 4) with dispatcher
# 02:20:10 DISPATCHER: job (0, 0, 4) finished
# 02:20:10 DISPATCHER: register_result: lock acquired
# 02:20:10 DISPATCHER: job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:20:10 job_id: (0, 0, 4)
# kwargs: {'config': {'lr': 0.00042412532047657, 'num_conv_layers': 1, 'num_filters_1': 27, 'optimizer': 'Adam'}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.08984375, 'info': {'test_accuracy': 0.9065, 'train_accuracy': 0.919921875, 'valid_accuracy': 0.91015625, 'model': 'Sequential(\n  (0): Conv2d(1, 27, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Flatten()\n  (4): Linear(in_features=4563, out_features=10, bias=True)\n  (5): LogSoftmax()\n)'}}
# exception: None
#
# 02:20:10 job_callback for (0, 0, 4) started
# 02:20:10 DISPATCHER: Trying to submit another job.
# 02:20:10 job_callback for (0, 0, 4) got condition
# 02:20:10 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:20:10 Only 2 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 02:20:10 HBMASTER: Trying to run another job!
# 02:20:10 job_callback for (0, 0, 4) finished
# 02:20:10 HBMASTER: schedule new run for iteration 0
# 02:20:10 HBMASTER: trying submitting job (0, 0, 6) to dispatcher
# 02:20:10 HBMASTER: submitting job (0, 0, 6) to dispatcher
# 02:20:10 DISPATCHER: trying to submit job (0, 0, 6)
# 02:20:10 DISPATCHER: trying to notify the job_runner thread.
# 02:20:10 HBMASTER: job (0, 0, 6) submitted to dispatcher
# 02:20:10 DISPATCHER: Trying to submit another job.
# 02:20:10 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:20:10 DISPATCHER: starting job (0, 0, 6) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:10 DISPATCHER: job (0, 0, 6) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:10 WORKER: start processing job (0, 0, 6)
# 02:20:10 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:20:10 WORKER: args: ()
# 02:20:10 WORKER: kwargs: {'config': {'lr': 0.0017874694916816638, 'num_conv_layers': 1, 'num_filters_1': 25, 'optimizer': 'SGD', 'sgd_momentum': 0.029856293783612178}, 'budget': 3.0, 'working_directory': '.'}
# 02:20:18 WORKER: done with job (0, 0, 6), trying to register it.
# 02:20:18 WORKER: registered result for job (0, 0, 6) with dispatcher
# 02:20:18 DISPATCHER: job (0, 0, 6) finished
# 02:20:18 DISPATCHER: register_result: lock acquired
# 02:20:18 DISPATCHER: job (0, 0, 6) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:20:18 job_id: (0, 0, 6)
# kwargs: {'config': {'lr': 0.0017874694916816638, 'num_conv_layers': 1, 'num_filters_1': 25, 'optimizer': 'SGD', 'sgd_momentum': 0.029856293783612178}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.271484375, 'info': {'test_accuracy': 0.7237, 'train_accuracy': 0.724365234375, 'valid_accuracy': 0.728515625, 'model': 'Sequential(\n  (0): Conv2d(1, 25, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Flatten()\n  (4): Linear(in_features=4225, out_features=10, bias=True)\n  (5): LogSoftmax()\n)'}}
# exception: None
#
# 02:20:18 job_callback for (0, 0, 6) started
# 02:20:18 DISPATCHER: Trying to submit another job.
# 02:20:18 job_callback for (0, 0, 6) got condition
# 02:20:18 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:20:18 Only 3 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 02:20:18 HBMASTER: Trying to run another job!
# 02:20:18 job_callback for (0, 0, 6) finished
# 02:20:18 ITERATION: Advancing config (0, 0, 4) to next budget 9.000000
# 02:20:18 HBMASTER: schedule new run for iteration 0
# 02:20:18 HBMASTER: trying submitting job (0, 0, 4) to dispatcher
# 02:20:18 HBMASTER: submitting job (0, 0, 4) to dispatcher
# 02:20:18 DISPATCHER: trying to submit job (0, 0, 4)
# 02:20:18 DISPATCHER: trying to notify the job_runner thread.
# 02:20:18 HBMASTER: job (0, 0, 4) submitted to dispatcher
# 02:20:18 DISPATCHER: Trying to submit another job.
# 02:20:18 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:20:18 DISPATCHER: starting job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:18 DISPATCHER: job (0, 0, 4) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:18 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:20:18 WORKER: start processing job (0, 0, 4)
# 02:20:18 WORKER: args: ()
# 02:20:18 WORKER: kwargs: {'config': {'lr': 0.00042412532047657, 'num_conv_layers': 1, 'num_filters_1': 27, 'optimizer': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# 02:20:22 DISPATCHER: Starting worker discovery
# 02:20:22 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 02:20:23 DISPATCHER: Finished worker discovery
# 02:20:40 WORKER: done with job (0, 0, 4), trying to register it.
# 02:20:40 WORKER: registered result for job (0, 0, 4) with dispatcher
# 02:20:40 DISPATCHER: job (0, 0, 4) finished
# 02:20:40 DISPATCHER: register_result: lock acquired
# 02:20:40 DISPATCHER: job (0, 0, 4) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:20:40 job_id: (0, 0, 4)
# kwargs: {'config': {'lr': 0.00042412532047657, 'num_conv_layers': 1, 'num_filters_1': 27, 'optimizer': 'Adam'}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.060546875, 'info': {'test_accuracy': 0.9315, 'train_accuracy': 0.96533203125, 'valid_accuracy': 0.939453125, 'model': 'Sequential(\n  (0): Conv2d(1, 27, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Flatten()\n  (4): Linear(in_features=4563, out_features=10, bias=True)\n  (5): LogSoftmax()\n)'}}
# exception: None
#
# 02:20:40 job_callback for (0, 0, 4) started
# 02:20:40 DISPATCHER: Trying to submit another job.
# 02:20:40 job_callback for (0, 0, 4) got condition
# 02:20:40 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:20:40 Only 1 run(s) for budget 9.000000 available, need more than 9 -> can't build model!
# 02:20:40 HBMASTER: Trying to run another job!
# 02:20:40 job_callback for (0, 0, 4) finished
# 02:20:40 start sampling a new configuration.
# 02:20:40 done sampling a new configuration.
# 02:20:40 HBMASTER: schedule new run for iteration 1
# 02:20:40 HBMASTER: trying submitting job (1, 0, 0) to dispatcher
# 02:20:40 HBMASTER: submitting job (1, 0, 0) to dispatcher
# 02:20:40 DISPATCHER: trying to submit job (1, 0, 0)
# 02:20:40 DISPATCHER: trying to notify the job_runner thread.
# 02:20:40 HBMASTER: job (1, 0, 0) submitted to dispatcher
# 02:20:40 DISPATCHER: Trying to submit another job.
# 02:20:40 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:20:40 DISPATCHER: starting job (1, 0, 0) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:40 DISPATCHER: job (1, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:40 WORKER: start processing job (1, 0, 0)
# 02:20:40 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:20:40 WORKER: args: ()
# 02:20:40 WORKER: kwargs: {'config': {'lr': 2.3789428852211415e-05, 'num_conv_layers': 3, 'num_filters_1': 18, 'optimizer': 'Adam', 'num_filters_2': 23, 'num_filters_3': 6}, 'budget': 3.0, 'working_directory': '.'}
# 02:20:51 WORKER: done with job (1, 0, 0), trying to register it.
# 02:20:51 WORKER: registered result for job (1, 0, 0) with dispatcher
# 02:20:51 DISPATCHER: job (1, 0, 0) finished
# 02:20:51 DISPATCHER: register_result: lock acquired
# 02:20:51 DISPATCHER: job (1, 0, 0) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:20:51 job_id: (1, 0, 0)
# kwargs: {'config': {'lr': 2.3789428852211415e-05, 'num_conv_layers': 3, 'num_filters_1': 18, 'optimizer': 'Adam', 'num_filters_2': 23, 'num_filters_3': 6}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.904296875, 'info': {'test_accuracy': 0.1054, 'train_accuracy': 0.10400390625, 'valid_accuracy': 0.095703125, 'model': 'Sequential(\n  (0): Conv2d(1, 18, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(18, 23, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Conv2d(23, 6, kernel_size=(3, 3), stride=(1, 1))\n  (7): ReLU()\n  (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (9): Flatten()\n  (10): Linear(in_features=6, out_features=10, bias=True)\n  (11): LogSoftmax()\n)'}}
# exception: None
#
# 02:20:51 job_callback for (1, 0, 0) started
# 02:20:51 DISPATCHER: Trying to submit another job.
# 02:20:51 job_callback for (1, 0, 0) got condition
# 02:20:51 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:20:51 Only 4 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 02:20:51 HBMASTER: Trying to run another job!
# 02:20:51 job_callback for (1, 0, 0) finished
# 02:20:51 start sampling a new configuration.
# 02:20:51 done sampling a new configuration.
# 02:20:51 HBMASTER: schedule new run for iteration 1
# 02:20:51 HBMASTER: trying submitting job (1, 0, 1) to dispatcher
# 02:20:51 HBMASTER: submitting job (1, 0, 1) to dispatcher
# 02:20:51 DISPATCHER: trying to submit job (1, 0, 1)
# 02:20:51 DISPATCHER: trying to notify the job_runner thread.
# 02:20:51 HBMASTER: job (1, 0, 1) submitted to dispatcher
# 02:20:51 DISPATCHER: Trying to submit another job.
# 02:20:51 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:20:51 DISPATCHER: starting job (1, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:51 DISPATCHER: job (1, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:51 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:20:51 WORKER: start processing job (1, 0, 1)
# 02:20:51 WORKER: args: ()
# 02:20:51 WORKER: kwargs: {'config': {'lr': 9.780201462842813e-05, 'num_conv_layers': 1, 'num_filters_1': 9, 'optimizer': 'SGD', 'sgd_momentum': 0.3324988565896108}, 'budget': 3.0, 'working_directory': '.'}
# 02:20:55 WORKER: done with job (1, 0, 1), trying to register it.
# 02:20:55 WORKER: registered result for job (1, 0, 1) with dispatcher
# 02:20:55 DISPATCHER: job (1, 0, 1) finished
# 02:20:55 DISPATCHER: register_result: lock acquired
# 02:20:55 DISPATCHER: job (1, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:20:55 job_id: (1, 0, 1)
# kwargs: {'config': {'lr': 9.780201462842813e-05, 'num_conv_layers': 1, 'num_filters_1': 9, 'optimizer': 'SGD', 'sgd_momentum': 0.3324988565896108}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.869140625, 'info': {'test_accuracy': 0.1363, 'train_accuracy': 0.13427734375, 'valid_accuracy': 0.130859375, 'model': 'Sequential(\n  (0): Conv2d(1, 9, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Flatten()\n  (4): Linear(in_features=1521, out_features=10, bias=True)\n  (5): LogSoftmax()\n)'}}
# exception: None
#
# 02:20:55 job_callback for (1, 0, 1) started
# 02:20:55 DISPATCHER: Trying to submit another job.
# 02:20:55 job_callback for (1, 0, 1) got condition
# 02:20:55 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:20:55 Only 5 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 02:20:55 HBMASTER: Trying to run another job!
# 02:20:55 job_callback for (1, 0, 1) finished
# 02:20:55 start sampling a new configuration.
# 02:20:55 done sampling a new configuration.
# 02:20:55 HBMASTER: schedule new run for iteration 1
# 02:20:55 HBMASTER: trying submitting job (1, 0, 2) to dispatcher
# 02:20:55 HBMASTER: submitting job (1, 0, 2) to dispatcher
# 02:20:55 DISPATCHER: trying to submit job (1, 0, 2)
# 02:20:55 DISPATCHER: trying to notify the job_runner thread.
# 02:20:55 HBMASTER: job (1, 0, 2) submitted to dispatcher
# 02:20:55 DISPATCHER: Trying to submit another job.
# 02:20:55 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:20:55 DISPATCHER: starting job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:55 DISPATCHER: job (1, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:20:55 WORKER: start processing job (1, 0, 2)
# 02:20:55 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:20:55 WORKER: args: ()
# 02:20:55 WORKER: kwargs: {'config': {'lr': 0.03771616580619741, 'num_conv_layers': 2, 'num_filters_1': 27, 'optimizer': 'SGD', 'num_filters_2': 26, 'sgd_momentum': 0.9477829590148589}, 'budget': 3.0, 'working_directory': '.'}
# 02:21:02 WORKER: shutting down now!
# 02:21:08 WORKER: done with job (1, 0, 2), trying to register it.
# 02:21:08 WORKER: registered result for job (1, 0, 2) with dispatcher
# 02:21:08 DISPATCHER: job (1, 0, 2) finished
# 02:21:08 DISPATCHER: register_result: lock acquired
# 02:21:08 DISPATCHER: job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:21:08 job_id: (1, 0, 2)
# kwargs: {'config': {'lr': 0.03771616580619741, 'num_conv_layers': 2, 'num_filters_1': 27, 'optimizer': 'SGD', 'num_filters_2': 26, 'sgd_momentum': 0.9477829590148589}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.0625, 'info': {'test_accuracy': 0.9454, 'train_accuracy': 0.962158203125, 'valid_accuracy': 0.9375, 'model': 'Sequential(\n  (0): Conv2d(1, 27, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(27, 26, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Flatten()\n  (7): Linear(in_features=416, out_features=10, bias=True)\n  (8): LogSoftmax()\n)'}}
# exception: None
#
# 02:21:08 job_callback for (1, 0, 2) started
# 02:21:08 DISPATCHER: Trying to submit another job.
# 02:21:08 job_callback for (1, 0, 2) got condition
# 02:21:08 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:21:08 Only 6 run(s) for budget 3.000000 available, need more than 9 -> can't build model!
# 02:21:08 HBMASTER: Trying to run another job!
# 02:21:08 job_callback for (1, 0, 2) finished
# 02:21:08 ITERATION: Advancing config (1, 0, 2) to next budget 9.000000
# 02:21:08 HBMASTER: schedule new run for iteration 1
# 02:21:08 HBMASTER: trying submitting job (1, 0, 2) to dispatcher
# 02:21:08 HBMASTER: submitting job (1, 0, 2) to dispatcher
# 02:21:08 DISPATCHER: trying to submit job (1, 0, 2)
# 02:21:08 DISPATCHER: trying to notify the job_runner thread.
# 02:21:08 HBMASTER: job (1, 0, 2) submitted to dispatcher
# 02:21:08 DISPATCHER: Trying to submit another job.
# 02:21:08 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:21:08 DISPATCHER: starting job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:21:08 DISPATCHER: job (1, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:21:08 WORKER: start processing job (1, 0, 2)
# 02:21:08 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:21:08 WORKER: args: ()
# 02:21:08 WORKER: kwargs: {'config': {'lr': 0.03771616580619741, 'num_conv_layers': 2, 'num_filters_1': 27, 'optimizer': 'SGD', 'num_filters_2': 26, 'sgd_momentum': 0.9477829590148589}, 'budget': 9.0, 'working_directory': '.'}
# 02:21:23 DISPATCHER: Starting worker discovery
# 02:21:23 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 02:21:23 DISPATCHER: Finished worker discovery
# 02:21:39 WORKER: done with job (1, 0, 2), trying to register it.
# 02:21:39 WORKER: registered result for job (1, 0, 2) with dispatcher
# 02:21:39 DISPATCHER: job (1, 0, 2) finished
# 02:21:39 DISPATCHER: register_result: lock acquired
# 02:21:39 DISPATCHER: job (1, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:21:39 job_id: (1, 0, 2)
# kwargs: {'config': {'lr': 0.03771616580619741, 'num_conv_layers': 2, 'num_filters_1': 27, 'optimizer': 'SGD', 'num_filters_2': 26, 'sgd_momentum': 0.9477829590148589}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.03515625, 'info': {'test_accuracy': 0.9655, 'train_accuracy': 0.992431640625, 'valid_accuracy': 0.96484375, 'model': 'Sequential(\n  (0): Conv2d(1, 27, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(27, 26, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Flatten()\n  (7): Linear(in_features=416, out_features=10, bias=True)\n  (8): LogSoftmax()\n)'}}
# exception: None
#
# 02:21:39 job_callback for (1, 0, 2) started
# 02:21:39 DISPATCHER: Trying to submit another job.
# 02:21:39 job_callback for (1, 0, 2) got condition
# 02:21:39 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:21:39 Only 2 run(s) for budget 9.000000 available, need more than 9 -> can't build model!
# 02:21:39 HBMASTER: Trying to run another job!
# 02:21:39 job_callback for (1, 0, 2) finished
# 02:21:39 start sampling a new configuration.
# 02:21:39 done sampling a new configuration.
# 02:21:39 HBMASTER: schedule new run for iteration 2
# 02:21:39 HBMASTER: trying submitting job (2, 0, 0) to dispatcher
# 02:21:39 HBMASTER: submitting job (2, 0, 0) to dispatcher
# 02:21:39 DISPATCHER: trying to submit job (2, 0, 0)
# 02:21:39 DISPATCHER: trying to notify the job_runner thread.
# 02:21:39 HBMASTER: job (2, 0, 0) submitted to dispatcher
# 02:21:39 DISPATCHER: Trying to submit another job.
# 02:21:39 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:21:39 DISPATCHER: starting job (2, 0, 0) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:21:39 DISPATCHER: job (2, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:21:39 WORKER: start processing job (2, 0, 0)
# 02:21:39 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:21:39 WORKER: args: ()
# 02:21:39 WORKER: kwargs: {'config': {'lr': 1.0246220595562363e-06, 'num_conv_layers': 3, 'num_filters_1': 29, 'optimizer': 'Adam', 'num_filters_2': 19, 'num_filters_3': 19}, 'budget': 9.0, 'working_directory': '.'}
# 02:22:14 WORKER: done with job (2, 0, 0), trying to register it.
# 02:22:14 WORKER: registered result for job (2, 0, 0) with dispatcher
# 02:22:14 DISPATCHER: job (2, 0, 0) finished
# 02:22:14 DISPATCHER: register_result: lock acquired
# 02:22:14 DISPATCHER: job (2, 0, 0) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:22:14 job_id: (2, 0, 0)
# kwargs: {'config': {'lr': 1.0246220595562363e-06, 'num_conv_layers': 3, 'num_filters_1': 29, 'optimizer': 'Adam', 'num_filters_2': 19, 'num_filters_3': 19}, 'budget': 9.0, 'working_directory': '.'}
# ...
# 02:31:29 job_callback for (10, 0, 1) got condition
# 02:31:29 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:31:29 HBMASTER: Trying to run another job!
# 02:31:29 job_callback for (10, 0, 1) finished
# 02:31:29 start sampling a new configuration.
# 02:31:29 best_vector: [0.6114860011211545, 0.551396631103314, 0.7746363639909642, 1, 0.9477276186090762, 0.13780939717980584, 0.7484103161793534], 0.00024214341180168507, 0.1782786997817842, 4.316901261672955e-05
# 02:31:29 done sampling a new configuration.
# 02:31:29 HBMASTER: schedule new run for iteration 10
# 02:31:29 HBMASTER: trying submitting job (10, 0, 2) to dispatcher
# 02:31:29 HBMASTER: submitting job (10, 0, 2) to dispatcher
# 02:31:29 DISPATCHER: trying to submit job (10, 0, 2)
# 02:31:29 DISPATCHER: trying to notify the job_runner thread.
# 02:31:29 HBMASTER: job (10, 0, 2) submitted to dispatcher
# 02:31:29 DISPATCHER: Trying to submit another job.
# 02:31:29 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:31:29 DISPATCHER: starting job (10, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:31:29 DISPATCHER: job (10, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:31:29 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:31:29 WORKER: start processing job (10, 0, 2)
# 02:31:29 WORKER: args: ()
# 02:31:29 WORKER: kwargs: {'config': {'lr': 0.0011413793359138628, 'num_conv_layers': 2, 'num_filters_1': 26, 'optimizer': 'SGD', 'num_filters_2': 31, 'sgd_momentum': 0.7409262130175599}, 'budget': 3.0, 'working_directory': '.'}
# 02:31:41 WORKER: done with job (10, 0, 2), trying to register it.
# 02:31:41 WORKER: registered result for job (10, 0, 2) with dispatcher
# 02:31:41 DISPATCHER: job (10, 0, 2) finished
# 02:31:41 DISPATCHER: register_result: lock acquired
# 02:31:41 DISPATCHER: job (10, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:31:41 job_id: (10, 0, 2)
# kwargs: {'config': {'lr': 0.0011413793359138628, 'num_conv_layers': 2, 'num_filters_1': 26, 'optimizer': 'SGD', 'num_filters_2': 31, 'sgd_momentum': 0.7409262130175599}, 'budget': 3.0, 'working_directory': '.'}
# result: {'loss': 0.396484375, 'info': {'test_accuracy': 0.5507, 'train_accuracy': 0.551025390625, 'valid_accuracy': 0.603515625, 'model': 'Sequential(\n  (0): Conv2d(1, 26, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(26, 31, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Flatten()\n  (7): Linear(in_features=496, out_features=10, bias=True)\n  (8): LogSoftmax()\n)'}}
# exception: None
#
# 02:31:41 job_callback for (10, 0, 2) started
# 02:31:41 DISPATCHER: Trying to submit another job.
# 02:31:41 job_callback for (10, 0, 2) got condition
# 02:31:41 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:31:41 HBMASTER: Trying to run another job!
# 02:31:41 job_callback for (10, 0, 2) finished
# 02:31:41 ITERATION: Advancing config (10, 0, 1) to next budget 9.000000
# 02:31:41 HBMASTER: schedule new run for iteration 10
# 02:31:41 HBMASTER: trying submitting job (10, 0, 1) to dispatcher
# 02:31:41 HBMASTER: submitting job (10, 0, 1) to dispatcher
# 02:31:41 DISPATCHER: trying to submit job (10, 0, 1)
# 02:31:41 DISPATCHER: trying to notify the job_runner thread.
# 02:31:41 HBMASTER: job (10, 0, 1) submitted to dispatcher
# 02:31:41 DISPATCHER: Trying to submit another job.
# 02:31:41 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:31:41 DISPATCHER: starting job (10, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:31:41 DISPATCHER: job (10, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:31:41 WORKER: start processing job (10, 0, 1)
# 02:31:41 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:31:41 WORKER: args: ()
# 02:31:41 WORKER: kwargs: {'config': {'lr': 0.0064004120359200676, 'num_conv_layers': 3, 'num_filters_1': 18, 'optimizer': 'Adam', 'num_filters_2': 30, 'num_filters_3': 31}, 'budget': 9.0, 'working_directory': '.'}
# 02:32:13 WORKER: done with job (10, 0, 1), trying to register it.
# 02:32:13 WORKER: registered result for job (10, 0, 1) with dispatcher
# 02:32:13 DISPATCHER: job (10, 0, 1) finished
# 02:32:13 DISPATCHER: register_result: lock acquired
# 02:32:13 DISPATCHER: job (10, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:32:13 job_id: (10, 0, 1)
# kwargs: {'config': {'lr': 0.0064004120359200676, 'num_conv_layers': 3, 'num_filters_1': 18, 'optimizer': 'Adam', 'num_filters_2': 30, 'num_filters_3': 31}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.03515625, 'info': {'test_accuracy': 0.9566, 'train_accuracy': 0.989013671875, 'valid_accuracy': 0.96484375, 'model': 'Sequential(\n  (0): Conv2d(1, 18, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(18, 30, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Conv2d(30, 31, kernel_size=(3, 3), stride=(1, 1))\n  (7): ReLU()\n  (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (9): Flatten()\n  (10): Linear(in_features=31, out_features=10, bias=True)\n  (11): LogSoftmax()\n)'}}
# exception: None
#
# 02:32:13 job_callback for (10, 0, 1) started
# 02:32:13 DISPATCHER: Trying to submit another job.
# 02:32:13 job_callback for (10, 0, 1) got condition
# 02:32:13 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:32:13 done building a new model for budget 9.000000 based on 8/14 split
# Best loss for this budget:0.031250
#
#
#
#
#
# 02:32:13 HBMASTER: Trying to run another job!
# 02:32:13 job_callback for (10, 0, 1) finished
# 02:32:13 start sampling a new configuration.
# 02:32:14 best_vector: [0.8658927537904278, 0.8891935276133507, 0.6494623680724768, 1, 0.7607602745328683, 0.3876069798483338, 0.8890526351785353], 3.6655715603885076e-06, 2.3007243838073794, 8.433469869576704e-06
# 02:32:14 done sampling a new configuration.
# 02:32:14 HBMASTER: schedule new run for iteration 11
# 02:32:14 HBMASTER: trying submitting job (11, 0, 0) to dispatcher
# 02:32:14 HBMASTER: submitting job (11, 0, 0) to dispatcher
# 02:32:14 DISPATCHER: trying to submit job (11, 0, 0)
# 02:32:14 DISPATCHER: trying to notify the job_runner thread.
# 02:32:14 HBMASTER: job (11, 0, 0) submitted to dispatcher
# 02:32:14 DISPATCHER: Trying to submit another job.
# 02:32:14 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:32:14 DISPATCHER: starting job (11, 0, 0) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:32:14 DISPATCHER: job (11, 0, 0) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:32:14 WORKER: start processing job (11, 0, 0)
# 02:32:14 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:32:14 WORKER: args: ()
# 02:32:14 WORKER: kwargs: {'config': {'lr': 0.021353239390659785, 'num_conv_layers': 3, 'num_filters_1': 22, 'optimizer': 'SGD', 'num_filters_2': 26, 'num_filters_3': 15, 'sgd_momentum': 0.88016210882675}, 'budget': 9.0, 'working_directory': '.'}
# 02:32:23 DISPATCHER: Starting worker discovery
# 02:32:23 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 02:32:23 DISPATCHER: Finished worker discovery
# 02:32:47 WORKER: done with job (11, 0, 0), trying to register it.
# 02:32:47 WORKER: registered result for job (11, 0, 0) with dispatcher
# 02:32:47 DISPATCHER: job (11, 0, 0) finished
# 02:32:47 DISPATCHER: register_result: lock acquired
# 02:32:47 DISPATCHER: job (11, 0, 0) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:32:47 job_id: (11, 0, 0)
# kwargs: {'config': {'lr': 0.021353239390659785, 'num_conv_layers': 3, 'num_filters_1': 22, 'optimizer': 'SGD', 'num_filters_2': 26, 'num_filters_3': 15, 'sgd_momentum': 0.88016210882675}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.064453125, 'info': {'test_accuracy': 0.9267, 'train_accuracy': 0.96240234375, 'valid_accuracy': 0.935546875, 'model': 'Sequential(\n  (0): Conv2d(1, 22, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(22, 26, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Conv2d(26, 15, kernel_size=(3, 3), stride=(1, 1))\n  (7): ReLU()\n  (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (9): Flatten()\n  (10): Linear(in_features=15, out_features=10, bias=True)\n  (11): LogSoftmax()\n)'}}
# exception: None
#
# 02:32:47 job_callback for (11, 0, 0) started
# 02:32:47 DISPATCHER: Trying to submit another job.
# 02:32:47 job_callback for (11, 0, 0) got condition
# 02:32:47 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:32:47 done building a new model for budget 9.000000 based on 8/15 split
# Best loss for this budget:0.031250
#
#
#
#
#
# 02:32:47 HBMASTER: Trying to run another job!
# 02:32:47 job_callback for (11, 0, 0) finished
# 02:32:47 start sampling a new configuration.
# 02:32:47 best_vector: [0.41304769489083715, 0.6107011041099454, 0.970471545304172, 0, 0.6293065082366228, 0.06498786176504873, 0.8046682654787961], 7.733417518673747e-05, 1.599173346313224, 0.00012367075171774807
# 02:32:47 done sampling a new configuration.
# 02:32:47 HBMASTER: schedule new run for iteration 11
# 02:32:47 HBMASTER: trying submitting job (11, 0, 1) to dispatcher
# 02:32:47 HBMASTER: submitting job (11, 0, 1) to dispatcher
# 02:32:47 DISPATCHER: trying to submit job (11, 0, 1)
# 02:32:47 DISPATCHER: trying to notify the job_runner thread.
# 02:32:47 HBMASTER: job (11, 0, 1) submitted to dispatcher
# 02:32:47 DISPATCHER: Trying to submit another job.
# 02:32:47 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:32:47 DISPATCHER: starting job (11, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:32:47 DISPATCHER: job (11, 0, 1) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:32:47 WORKER: start processing job (11, 0, 1)
# 02:32:47 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:32:47 WORKER: args: ()
# 02:32:47 WORKER: kwargs: {'config': {'lr': 0.00011620865493760173, 'num_conv_layers': 2, 'num_filters_1': 32, 'optimizer': 'Adam', 'num_filters_2': 22}, 'budget': 9.0, 'working_directory': '.'}
# 02:33:23 DISPATCHER: Starting worker discovery
# 02:33:23 DISPATCHER: Found 1 potential workers, 1 currently in the pool.
# 02:33:23 DISPATCHER: Finished worker discovery
# 02:33:26 WORKER: done with job (11, 0, 1), trying to register it.
# 02:33:26 WORKER: registered result for job (11, 0, 1) with dispatcher
# 02:33:26 DISPATCHER: job (11, 0, 1) finished
# 02:33:26 DISPATCHER: register_result: lock acquired
# 02:33:26 DISPATCHER: job (11, 0, 1) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:33:26 job_id: (11, 0, 1)
# kwargs: {'config': {'lr': 0.00011620865493760173, 'num_conv_layers': 2, 'num_filters_1': 32, 'optimizer': 'Adam', 'num_filters_2': 22}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.109375, 'info': {'test_accuracy': 0.8791, 'train_accuracy': 0.895263671875, 'valid_accuracy': 0.890625, 'model': 'Sequential(\n  (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(32, 22, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Flatten()\n  (7): Linear(in_features=352, out_features=10, bias=True)\n  (8): LogSoftmax()\n)'}}
# exception: None
#
# 02:33:26 job_callback for (11, 0, 1) started
# 02:33:26 DISPATCHER: Trying to submit another job.
# 02:33:26 job_callback for (11, 0, 1) got condition
# 02:33:26 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:33:26 done building a new model for budget 9.000000 based on 8/16 split
# Best loss for this budget:0.031250
#
#
#
#
#
# 02:33:26 HBMASTER: Trying to run another job!
# 02:33:26 job_callback for (11, 0, 1) finished
# 02:33:26 start sampling a new configuration.
# 02:33:26 best_vector: [0.88305861772325, 0.6924265667723275, 0.7416408510408761, 1, 0.9068602133781865, 0.009194604633998071, 0.9244597169797659], 5.004939032175915e-06, 4.9672901040075175, 2.486098412568838e-05
# 02:33:26 done sampling a new configuration.
# 02:33:26 HBMASTER: schedule new run for iteration 11
# 02:33:26 HBMASTER: trying submitting job (11, 0, 2) to dispatcher
# 02:33:26 HBMASTER: submitting job (11, 0, 2) to dispatcher
# 02:33:26 DISPATCHER: trying to submit job (11, 0, 2)
# 02:33:26 DISPATCHER: trying to notify the job_runner thread.
# 02:33:26 HBMASTER: job (11, 0, 2) submitted to dispatcher
# 02:33:26 HBMASTER: running jobs: 1, queue sizes: (0, 1) -> wait
# 02:33:26 DISPATCHER: Trying to submit another job.
# 02:33:26 DISPATCHER: starting job (11, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:33:26 DISPATCHER: job (11, 0, 2) dispatched on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056
# 02:33:26 WORKER: start processing job (11, 0, 2)
# 02:33:26 DISPATCHER: jobs to submit = 0, number of idle workers = 0 -> waiting!
# 02:33:26 WORKER: args: ()
# 02:33:26 WORKER: kwargs: {'config': {'lr': 0.02601914902931912, 'num_conv_layers': 3, 'num_filters_1': 25, 'optimizer': 'SGD', 'num_filters_2': 30, 'num_filters_3': 4, 'sgd_momentum': 0.9152151198099683}, 'budget': 9.0, 'working_directory': '.'}
# 02:34:02 WORKER: done with job (11, 0, 2), trying to register it.
# 02:34:02 WORKER: registered result for job (11, 0, 2) with dispatcher
# 02:34:02 DISPATCHER: job (11, 0, 2) finished
# 02:34:02 DISPATCHER: register_result: lock acquired
# 02:34:02 DISPATCHER: job (11, 0, 2) on hpbandster.run_bohb_run_1.worker.DESKTOP-HNPU7LV.3938016056 finished
# 02:34:02 job_id: (11, 0, 2)
# kwargs: {'config': {'lr': 0.02601914902931912, 'num_conv_layers': 3, 'num_filters_1': 25, 'optimizer': 'SGD', 'num_filters_2': 30, 'num_filters_3': 4, 'sgd_momentum': 0.9152151198099683}, 'budget': 9.0, 'working_directory': '.'}
# result: {'loss': 0.107421875, 'info': {'test_accuracy': 0.8971, 'train_accuracy': 0.938232421875, 'valid_accuracy': 0.892578125, 'model': 'Sequential(\n  (0): Conv2d(1, 25, kernel_size=(3, 3), stride=(1, 1))\n  (1): ReLU()\n  (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (3): Conv2d(25, 30, kernel_size=(3, 3), stride=(1, 1))\n  (4): ReLU()\n  (5): MaxPool2d(kernel_size=2, stride=3, padding=0, dilation=1, ceil_mode=False)\n  (6): Conv2d(30, 4, kernel_size=(3, 3), stride=(1, 1))\n  (7): ReLU()\n  (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)\n  (9): Flatten()\n  (10): Linear(in_features=4, out_features=10, bias=True)\n  (11): LogSoftmax()\n)'}}
# exception: None
#
# 02:34:02 job_callback for (11, 0, 2) started
# 02:34:02 DISPATCHER: Trying to submit another job.
# 02:34:02 job_callback for (11, 0, 2) got condition
# 02:34:02 DISPATCHER: jobs to submit = 0, number of idle workers = 1 -> waiting!
# 02:34:02 done building a new model for budget 9.000000 based on 8/17 split
# Best loss for this budget:0.031250
#
#
#
#
#
# 02:34:02 HBMASTER: Trying to run another job!
# 02:34:02 job_callback for (11, 0, 2) finished
# 02:34:02 HBMASTER: shutdown initiated, shutdown_workers = True
# 02:34:02 WORKER: shutting down now!
# 02:34:02 DISPATCHER: Dispatcher shutting down
# Write result to file .\bohb_result.pkl
# 02:34:02 DISPATCHER: Trying to submit another job.
# 02:34:02 DISPATCHER: job_runner shutting down
# 02:34:02 DISPATCHER: discover_workers shutting down
# 02:34:02 DISPATCHER: 'discover_worker' thread exited
# 02:34:02 DISPATCHER: 'job_runner' thread exited
# 02:34:02 DISPATCHER: shut down complete
# 02:36:02 WORKER: shutting down now!

# %% [markdown]
# ### Evaluate result
#
# The result object which we dumped to disk contains all the runs with the different configurations.
# Here we will analyse it further. The [HpBandSter Analysis Example](https://automl.github.io/HpBandSter/build/html/auto_examples/plot_example_6_analysis.html) is there, if you need help.

# %%
#  load a saved result object if necessary
with open(result_file, 'rb') as f:
    result = pickle.load(f)
    
#print(result.data)

# %% [markdown]
# **Task:** Print the model of the best run, evaluated on the largest budget, with it's final validation error. *Tipp:* Have a look at the [HpBandSter Result Docs](https://automl.github.io/HpBandSter/build/html/core/result.html).

# %%
# START TODO ################
id2conf = result.get_id2config_mapping()
incumbent = result.get_incumbent_id()

best_model = result.get_runs_by_id(incumbent)
print("Best configuration: ",id2conf[incumbent]['config'])
print("Best model: ",best_model[-1]['info']['model'])
print("Budget: ",best_model[-1]['budget'])
print("Final validation error : ",best_model[-1]['loss'])
# END TODO ################
# Out:
# Best configuration:  {'lr': 0.007299537091356352, 'num_conv_layers': 1, 'num_filters_1': 31, 'optimizer': 'Adam'}
# Best model:  Sequential(
#   (0): Conv2d(1, 31, kernel_size=(3, 3), stride=(1, 1))
#   (1): ReLU()
#   (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (3): Flatten()
#   (4): Linear(in_features=5239, out_features=10, bias=True)
#   (5): LogSoftmax()
# )
# Budget:  9.0
# Final validation error :  0.03125

# %% [markdown]
# We can gain deeper insight through plotting results. Thanks to the [HpBandSter Visualization Module](https://automl.github.io/HpBandSter/build/html/core/visualization.html) plotting is a one-liner.

# %%
import hpbandster.visualization as hpvis

all_runs = result.get_all_runs()
id2conf = result.get_id2config_mapping()

hpvis.losses_over_time(all_runs)


lrc=result.get_learning_curves()
hpvis.interactive_HBS_plot(lrc, tool_tip_strings=hpvis.default_tool_tips(result, lrc))
#plt.savefig("all_runs.png")
# Out:
# (<matplotlib.figure.Figure at 0x19bcca592b0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19bc1fa7c50>,
#  <matplotlib.widgets.CheckButtons at 0x19bcc836940>,
#  <matplotlib.widgets.Button at 0x19bcac3f080>,
#  <matplotlib.widgets.Button at 0x19bcb066b70>)

# %% [markdown]
# First let's see, if we really can evaluate more configurations when makeing use of low budget runs.
#
# **Task:** Plot the finished runs over time. How many runs per minute did finish for the individual budgets (only approximately)?
#
# **Answer:** budget = 9 : 1 run , budget = 3 : 5 runs , budget = 1 : 8 runs

# %%
# START TODO ##################
#finished_runs= result.get_all_runs(only_largest_budget=True)
hpvis.finished_runs_over_time(all_runs)
#plt.savefig("finished_runs.png")
# Out:
# (<matplotlib.figure.Figure at 0x19bcc7d6c18>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19bcca7c860>)

# %% [markdown]
# Evaluating configurations on lower budgets doesn't make sense - even if they are faster - if the performance ranking isn't consistent from low to high budget. This means, that the loss rankings for configurations should correlate. In simplified terms: The best configuration after one epoch should also be the best after nine epochs, the second best should stay the second best and so on.
#
# **Task:** Plot correlations of rankings across budgets. Are the correlations high enough?
#
# **Answer:** **TODO**

# %%
# START TODO ##################

hpvis.correlation_across_budgets(result)
# Out:
# (<matplotlib.figure.Figure at 0x19bcb1c4588>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19bc39bc6a0>)

# %% [markdown]
# We usually assume, that training on a higher budget (number of epochs) and sampling more configurations can lead to better results. Let's check this.
#
# **Task:** Plot the losses over time. Do our assumptions hold true? Why?
#
# **Answer:** NO.
# 1. We can see that many of the configurations from budget=3 have the same loss as budget=1 even after many iterations.
# 2. we can also see thet there are more configurations sampled for budget=1, yet the losses remain high

# %%
# START TODO ##################
hpvis.losses_over_time(all_runs)
# Out:
# (<matplotlib.figure.Figure at 0x19bcb15b630>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19bbe4ae908>)

# %% [markdown]
# Remember that BOHB uses a model after some time to improve the configuation sampling. We can check, if the BO-sampled configurations work better than the random-sampled.
#
# **Task:** Plot loss histograms for all budgets only with BO-sampled and only with random-sampled configurations (6 histograms). Is the BO-sampling useful?
#
# **Answer:** We can see a significant reduction in the loss only for budget=9

# %%
# START TODO ##################
hpvis.performance_histogram_model_vs_random(all_runs, id2conf)
# Out:
# (<matplotlib.figure.Figure at 0x19bc5857e10>,
#  array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000019BCB15B978>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000019BDAD16BA8>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019BC588C978>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000019BC201DB38>],
#         [<matplotlib.axes._subplots.AxesSubplot object at 0x0000019BC1F878D0>,
#          <matplotlib.axes._subplots.AxesSubplot object at 0x0000019BBE7D6208>]],
#        dtype=object))

# %% [markdown]
# ### Your Feedback on Exercise 6.2
#
#
# 1. Utilities provided in the hpvis is extremely time saving and helps very much for analysis of result
# 2. Maximim time was spent in building  network in function 'get_conv_model'(3 hours)
